# %% [markdown]
# ### Import Library Dependencies

# %%
import os
import sys
import traceback
import logging as log
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from microgrid_env import MicrogridEnv

log.basicConfig(format="Line:%(lineno)d-%(funcName)s-%(levelname)s:  %(message)s")
log.getLogger().setLevel(log.INFO)

# %% [markdown]
# ### Environment Data Pre-processing

# %%
def convert_weekday(wkd: str) -> str:
    if wkd in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']:
        return 'week'
    else:
        return wkd.lower()

# %%
df = pd.read_csv("load_profile_data_nov2024.csv", header=0)
df['timestamp'] = pd.to_datetime(df['entry_time'], format="mixed")
df['ts_hour'] = df['timestamp'].dt.hour

# One-hot encode the Weekday field
df['weekday_fmt'] = df['weekday'].map(lambda wkd: convert_weekday(wkd))
df['day_week'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'week' else 0)
df['day_saturday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'saturday' else 0)
df['day_sunday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'sunday' else 0)

# One-hot encode the TOU Timeslot field
df['tou_offpeak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'o' else 0)
df['tou_standard'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 's' else 0)
df['tou_peak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'p' else 0)

# Convert hour field to unit circle coordinates
df['ts_hour_sin'] = np.sin( df['ts_hour'] )
df['ts_hour_cos'] = np.cos( df['ts_hour'] )

df.set_index('timestamp', inplace=True)

df.drop(['entry_time', 'ts_hour', 'weekday', 'weekday_fmt', 'tou_time_slot'], axis=1, inplace=True)

load_profile_df = df[['ts_hour_sin', 'ts_hour_cos', 'tou_offpeak', 'tou_standard', 'tou_peak', 'day_week', 'day_saturday', 'day_sunday', 'site_load_energy', 'solar_prod_energy', 'solar_ctlr_setpoint', 'grid_import_energy']]

# Filter the load profile data for a specific date period
load_profile_filtered_df = load_profile_df.loc['2024-11-04':'2024-11-10']

# %% [markdown]
# ### Run Environment

# %%
env = MicrogridEnv(data = load_profile_filtered_df, 
                   grid_notified_maximum_demand = 2000.0, 
                   bess_capacity = 3000.0, 
                   bess_cycle_efficiency = 0.9, 
                   bess_step_sizes = [1500.0, 1000.0, 500.0, 0.0, 500.0, 1000.0, 1500.0], 
                   tou_peak_tariff = 5.0, 
                   tou_standard_tariff = 2.0, 
                   tou_offpeak_tariff = 1.0, 
                   solar_ppa_tariff = 1.4,
                   debug_flag = True)

# %%
# Action Space:
# {0: 'charge-1500', 1: 'charge-1000', 2: 'charge-500', 3: 'do-nothing', 4: 'discharge-500', 5: 'discharge-1000', 6: 'discharge-1500'}

episode_reward = 0.0

state, reward, done = env.reset()

episode_reward += reward

for idx in range(168):

    action = env.rule_based_policy()

    state, reward, done = env.step(action=action)

    episode_reward += reward
# Out:
# Environment Defaults:
#
#           Grid Notified Maximum Demand: 2000.0 kVA
#           BESS Capacity: 3000.0 kWh
#           BESS Actions: charge-1500, charge-1000, charge-500, do-nothing, discharge-500, discharge-1000, discharge-1500
#
#
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2024-11-04 00:00:00 to 2024-11-10 23:00:00
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ts_hour_sin          168 non-null    float64
#  1   ts_hour_cos          168 non-null    float64
#  2   tou_offpeak          168 non-null    int64
#  3   tou_standard         168 non-null    int64
#  4   tou_peak             168 non-null    int64
#  5   day_week             168 non-null    int64
#  6   day_saturday         168 non-null    int64
#  7   day_sunday           168 non-null    int64
#  8   site_load_energy     168 non-null    float64
#  9   solar_prod_energy    168 non-null    float64
#  10  solar_ctlr_setpoint  168 non-null    float64
#  11  grid_import_energy   168 non-null    float64
# dtypes: float64(6), int64(6)
# memory usage: 17.1 KB
# None
#
#
#
#             [0] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [0] Environment State ->
#                   hour_sin:  0.0000
#                   hour_cos:  1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1031.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1031.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [0] Selected BESS Action -> do-nothing
#
#
#             [0] BESS SoC Reward:  1000.00
#
#
#           [0] Calculated Reward ->  1000.000
#
#
#             [1] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [1] Environment State ->
#                   hour_sin:  0.8415
#                   hour_cos:  0.5403
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1191.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1191.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [1] Selected BESS Action -> do-nothing
#
#
#             [1] BESS SoC Reward:  1000.00
#
#
#           [1] Calculated Reward ->  1000.000
#
#
#             [2] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [2] Environment State ->
#                   hour_sin:  0.9093
#                   hour_cos: -0.4161
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1233.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1233.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [2] Selected BESS Action -> do-nothing
#
#
#             [2] BESS SoC Reward:  1000.00
#
#
#           [2] Calculated Reward ->  1000.000
#
#
#             [3] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [3] Environment State ->
#                   hour_sin:  0.1411
#                   hour_cos: -0.9900
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1145.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1145.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [3] Selected BESS Action -> do-nothing
#
#
#             [3] BESS SoC Reward:  1000.00
#
#
#           [3] Calculated Reward ->  1000.000
#
#
#             [4] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [4] Environment State ->
#                   hour_sin: -0.7568
#                   hour_cos: -0.6536
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1247.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1247.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [4] Selected BESS Action -> do-nothing
#
#
#             [4] BESS SoC Reward:  1000.00
#
#
#           [4] Calculated Reward ->  1000.000
#
#
#             [5] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  30.52
#                     Solar Full Production Energy:  30.52
#                     Solar Surplus Production Energy:  0.00
#
#
#           [5] Environment State ->
#                   hour_sin: -0.9589
#                   hour_cos:  0.2837
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1356.72 (kWh)
#                   solar_prod_energy:  30.52 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  2.25 (%)
#                   grid_import_energy:  1326.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [5] Selected BESS Action -> do-nothing
#
#
#             [5] BESS SoC Reward:  1000.00
#
#
#           [5] Calculated Reward ->  1000.000
#
#
#             [6] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  186.90
#                     Solar Full Production Energy:  186.90
#                     Solar Surplus Production Energy:  0.00
#
#
#           [6] Environment State ->
#                   hour_sin: -0.2794
#                   hour_cos:  0.9602
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1340.90 (kWh)
#                   solar_prod_energy:  186.90 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  13.94 (%)
#                   grid_import_energy:  1154.00 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [6] Selected BESS Action -> discharge-500
#
#
#             [6] Current BESS Discharge Savings:  2500.00
#
#
#             [6] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  83.33
#
#
#             [6] BESS SoC Reward:  833.30
#
#
#           [6] Calculated Reward ->  2499.970
#
#
#             [7] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  545.90
#                     Solar Full Production Energy:  545.90
#                     Solar Surplus Production Energy:  0.00
#
#
#           [7] Environment State ->
#                   hour_sin:  0.6570
#                   hour_cos:  0.7539
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1218.30 (kWh)
#                   solar_prod_energy:  545.90 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  44.81 (%)
#                   grid_import_energy:  672.40 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [7] Selected BESS Action -> discharge-500
#
#
#             [7] Current BESS Discharge Savings:  2500.00
#
#
#             [7] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  66.67
#
#
#             [7] BESS SoC Reward:  0.00
#
#
#           [7] Calculated Reward ->  1666.670
#
#
#             [8] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  832.30
#                     Solar Full Production Energy:  832.30
#                     Solar Surplus Production Energy:  0.00
#
#
#           [8] Environment State ->
#                   hour_sin:  0.9894
#                   hour_cos: -0.1455
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1263.20 (kWh)
#                   solar_prod_energy:  832.30 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  65.89 (%)
#                   grid_import_energy:  430.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [8] Selected BESS Action -> discharge-500
#
#
#             [8] Current BESS Discharge Savings:  2154.50
#
#
#             [8] Future BESS Charge Cost:  718.17
#                            BESS Grid Charge Energy:  478.78
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  52.30
#
#
#             [8] BESS SoC Reward:  0.00
#
#
#           [8] Calculated Reward ->  1436.330
#
#
#             [9] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  1123.60
#                     Solar Full Production Energy:  1123.60
#                     Solar Surplus Production Energy:  0.00
#
#
#           [9] Environment State ->
#                   hour_sin:  0.4121
#                   hour_cos: -0.9111
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1359.30 (kWh)
#                   solar_prod_energy:  1123.60 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  82.66 (%)
#                   grid_import_energy:  235.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1569.10 (kWh)
#                   bess_soc:  52.30
#                   done: False
#
#
#           [9] Selected BESS Action -> charge-500
#
#
#             [9] Current BESS Charge Cost:  1000.00
#
#
#             [9] Future BESS Discharge Savings:  1350.00
#
#
#             [9] BESS SoC Reward:  0.00
#
#
#           [9] Calculated Reward ->  350.000
#
#
#             [10] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.94
#                     Solar Production Energy:  1198.20
#                     Solar Full Production Energy:  1270.59
#                     Solar Surplus Production Energy:  72.39
#
#
#           [10] Environment State ->
#                   hour_sin: -0.5440
#                   hour_cos: -0.8391
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1272.70 (kWh)
#                   solar_prod_energy:  1198.20 (kWh)
#                   solar_ctlr_setpoint:  94.30 (%)
#                   solar_vs_load_ratio:  94.15 (%)
#                   grid_import_energy:  74.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2069.10 (kWh)
#                   bess_soc:  68.97
#                   done: False
#
#
#           [10] Selected BESS Action -> charge-1500
#
#
#             [10] Current BESS Charge Cost:  1834.84
#
#
#             [10] Future BESS Discharge Savings:  2448.74
#
#
#             [10] BESS SoC Reward:  1000.00
#
#
#           [10] Calculated Reward ->  1613.900
#
#
#             [11] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.79
#                     Solar Production Energy:  1114.00
#                     Solar Full Production Energy:  1404.03
#                     Solar Surplus Production Energy:  290.03
#
#
#           [11] Environment State ->
#                   hour_sin: -1.0000
#                   hour_cos:  0.0044
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1194.60 (kWh)
#                   solar_prod_energy:  1114.00 (kWh)
#                   solar_ctlr_setpoint:  79.34 (%)
#                   solar_vs_load_ratio:  93.25 (%)
#                   grid_import_energy:  80.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [11] Selected BESS Action -> do-nothing
#
#
#             [11] BESS SoC Reward:  1000.00
#
#
#           [11] Calculated Reward ->  1000.000
#
#
#             [12] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.76
#                     Solar Production Energy:  1212.70
#                     Solar Full Production Energy:  1601.37
#                     Solar Surplus Production Energy:  388.67
#
#
#           [12] Environment State ->
#                   hour_sin: -0.5366
#                   hour_cos:  0.8439
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1296.00 (kWh)
#                   solar_prod_energy:  1212.70 (kWh)
#                   solar_ctlr_setpoint:  75.73 (%)
#                   solar_vs_load_ratio:  93.57 (%)
#                   grid_import_energy:  83.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [12] Selected BESS Action -> do-nothing
#
#
#             [12] BESS SoC Reward:  1000.00
#
#
#           [12] Calculated Reward ->  1000.000
#
#
#             [13] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.81
#                     Solar Production Energy:  984.30
#                     Solar Full Production Energy:  1211.00
#                     Solar Surplus Production Energy:  226.70
#
#
#           [13] Environment State ->
#                   hour_sin:  0.4202
#                   hour_cos:  0.9074
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1223.80 (kWh)
#                   solar_prod_energy:  984.30 (kWh)
#                   solar_ctlr_setpoint:  81.28 (%)
#                   solar_vs_load_ratio:  80.43 (%)
#                   grid_import_energy:  239.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [13] Selected BESS Action -> do-nothing
#
#
#             [13] BESS SoC Reward:  1000.00
#
#
#           [13] Calculated Reward ->  1000.000
#
#
#             [14] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.84
#                     Solar Production Energy:  885.20
#                     Solar Full Production Energy:  1058.74
#                     Solar Surplus Production Energy:  173.54
#
#
#           [14] Environment State ->
#                   hour_sin:  0.9906
#                   hour_cos:  0.1367
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1216.00 (kWh)
#                   solar_prod_energy:  885.20 (kWh)
#                   solar_ctlr_setpoint:  83.61 (%)
#                   solar_vs_load_ratio:  72.80 (%)
#                   grid_import_energy:  330.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [14] Selected BESS Action -> do-nothing
#
#
#             [14] BESS SoC Reward:  1000.00
#
#
#           [14] Calculated Reward ->  1000.000
#
#
#             [15] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.93
#                     Solar Production Energy:  689.90
#                     Solar Full Production Energy:  741.58
#                     Solar Surplus Production Energy:  51.68
#
#
#           [15] Environment State ->
#                   hour_sin:  0.6503
#                   hour_cos: -0.7597
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1133.50 (kWh)
#                   solar_prod_energy:  689.90 (kWh)
#                   solar_ctlr_setpoint:  93.03 (%)
#                   solar_vs_load_ratio:  60.86 (%)
#                   grid_import_energy:  443.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [15] Selected BESS Action -> do-nothing
#
#
#             [15] BESS SoC Reward:  1000.00
#
#
#           [15] Calculated Reward ->  1000.000
#
#
#             [16] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.98
#                     Solar Production Energy:  286.90
#                     Solar Full Production Energy:  292.94
#                     Solar Surplus Production Energy:  6.04
#
#
#           [16] Environment State ->
#                   hour_sin: -0.2879
#                   hour_cos: -0.9577
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1051.50 (kWh)
#                   solar_prod_energy:  286.90 (kWh)
#                   solar_ctlr_setpoint:  97.94 (%)
#                   solar_vs_load_ratio:  27.28 (%)
#                   grid_import_energy:  764.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [16] Selected BESS Action -> do-nothing
#
#
#             [16] BESS SoC Reward:  1000.00
#
#
#           [16] Calculated Reward ->  1000.000
#
#
#             [17] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  109.30
#                     Solar Full Production Energy:  109.30
#                     Solar Surplus Production Energy:  0.00
#
#
#           [17] Environment State ->
#                   hour_sin: -0.9614
#                   hour_cos: -0.2752
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1337.10 (kWh)
#                   solar_prod_energy:  109.30 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  8.17 (%)
#                   grid_import_energy:  1227.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [17] Selected BESS Action -> discharge-500
#
#
#             [17] Current BESS Discharge Savings:  2500.00
#
#
#             [17] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  83.33
#
#
#             [17] BESS SoC Reward:  833.30
#
#
#           [17] Calculated Reward ->  2499.970
#
#
#             [18] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  30.26
#                     Solar Full Production Energy:  30.26
#                     Solar Surplus Production Energy:  0.00
#
#
#           [18] Environment State ->
#                   hour_sin: -0.7510
#                   hour_cos:  0.6603
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1117.86 (kWh)
#                   solar_prod_energy:  30.26 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  2.71 (%)
#                   grid_import_energy:  1087.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [18] Selected BESS Action -> discharge-500
#
#
#             [18] Current BESS Discharge Savings:  2500.00
#
#
#             [18] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  66.67
#
#
#             [18] BESS SoC Reward:  0.00
#
#
#           [18] Calculated Reward ->  1666.670
#
#
#             [19] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [19] Environment State ->
#                   hour_sin:  0.1499
#                   hour_cos:  0.9887
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1082.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1082.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [19] Selected BESS Action -> charge-500
#
#
#             [19] Current BESS Charge Cost:  1000.00
#
#
#             [19] Future BESS Discharge Savings:  1350.00
#
#
#             [19] BESS SoC Reward:  833.30
#
#
#           [19] Calculated Reward ->  1183.300
#
#
#             [20] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [20] Environment State ->
#                   hour_sin:  0.9129
#                   hour_cos:  0.4081
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1139.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1139.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [20] Selected BESS Action -> charge-500
#
#
#             [20] Current BESS Charge Cost:  1000.00
#
#
#             [20] Future BESS Discharge Savings:  1350.00
#
#
#             [20] BESS SoC Reward:  1000.00
#
#
#           [20] Calculated Reward ->  1350.000
#
#
#             [21] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [21] Environment State ->
#                   hour_sin:  0.8367
#                   hour_cos: -0.5477
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1074.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1074.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [21] Selected BESS Action -> do-nothing
#
#
#             [21] BESS SoC Reward:  1000.00
#
#
#           [21] Calculated Reward ->  1000.000
#
#
#             [22] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [22] Environment State ->
#                   hour_sin: -0.0089
#                   hour_cos: -1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1126.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1126.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [22] Selected BESS Action -> do-nothing
#
#
#             [22] BESS SoC Reward:  1000.00
#
#
#           [22] Calculated Reward ->  1000.000
#
#
#             [23] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [23] Environment State ->
#                   hour_sin: -0.8462
#                   hour_cos: -0.5328
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1438.50 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1438.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [23] Selected BESS Action -> do-nothing
#
#
#             [23] BESS SoC Reward:  1000.00
#
#
#           [23] Calculated Reward ->  1000.000
#
#
#             [24] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [24] Environment State ->
#                   hour_sin:  0.0000
#                   hour_cos:  1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1255.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1255.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [24] Selected BESS Action -> do-nothing
#
#
#             [24] BESS SoC Reward:  1000.00
#
#
#           [24] Calculated Reward ->  1000.000
#
#
#             [25] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [25] Environment State ->
#                   hour_sin:  0.8415
#                   hour_cos:  0.5403
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1339.70 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1339.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [25] Selected BESS Action -> do-nothing
#
#
#             [25] BESS SoC Reward:  1000.00
#
#
#           [25] Calculated Reward ->  1000.000
#
#
#             [26] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [26] Environment State ->
#                   hour_sin:  0.9093
#                   hour_cos: -0.4161
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1292.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1292.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [26] Selected BESS Action -> do-nothing
#
#
#             [26] BESS SoC Reward:  1000.00
#
#
#           [26] Calculated Reward ->  1000.000
#
#
#             [27] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [27] Environment State ->
#                   hour_sin:  0.1411
#                   hour_cos: -0.9900
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1201.40 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1201.40 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [27] Selected BESS Action -> do-nothing
#
#
#             [27] BESS SoC Reward:  1000.00
#
#
#           [27] Calculated Reward ->  1000.000
#
#
#             [28] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [28] Environment State ->
#                   hour_sin: -0.7568
#                   hour_cos: -0.6536
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1159.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1159.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [28] Selected BESS Action -> do-nothing
#
#
#             [28] BESS SoC Reward:  1000.00
#
#
#           [28] Calculated Reward ->  1000.000
#
#
#             [29] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  10.97
#                     Solar Full Production Energy:  10.97
#                     Solar Surplus Production Energy:  0.00
#
#
#           [29] Environment State ->
#                   hour_sin: -0.9589
#                   hour_cos:  0.2837
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1147.87 (kWh)
#                   solar_prod_energy:  10.97 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.96 (%)
#                   grid_import_energy:  1136.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [29] Selected BESS Action -> do-nothing
#
#
#             [29] BESS SoC Reward:  1000.00
#
#
#           [29] Calculated Reward ->  1000.000
#
#
#             [30] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  102.91
#                     Solar Full Production Energy:  102.91
#                     Solar Surplus Production Energy:  0.00
#
#
#           [30] Environment State ->
#                   hour_sin: -0.2794
#                   hour_cos:  0.9602
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1269.61 (kWh)
#                   solar_prod_energy:  102.91 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  8.11 (%)
#                   grid_import_energy:  1166.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [30] Selected BESS Action -> discharge-500
#
#
#             [30] Current BESS Discharge Savings:  2500.00
#
#
#             [30] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  83.33
#
#
#             [30] BESS SoC Reward:  833.30
#
#
#           [30] Calculated Reward ->  2499.970
#
#
#             [31] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  212.85
#                     Solar Full Production Energy:  212.85
#                     Solar Surplus Production Energy:  0.00
#
#
#           [31] Environment State ->
#                   hour_sin:  0.6570
#                   hour_cos:  0.7539
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1284.45 (kWh)
#                   solar_prod_energy:  212.85 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  16.57 (%)
#                   grid_import_energy:  1071.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [31] Selected BESS Action -> discharge-500
#
#
#             [31] Current BESS Discharge Savings:  2500.00
#
#
#             [31] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  66.67
#
#
#             [31] BESS SoC Reward:  0.00
#
#
#           [31] Calculated Reward ->  1666.670
#
#
#             [32] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  310.70
#                     Solar Full Production Energy:  310.70
#                     Solar Surplus Production Energy:  0.00
#
#
#           [32] Environment State ->
#                   hour_sin:  0.9894
#                   hour_cos: -0.1455
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1302.30 (kWh)
#                   solar_prod_energy:  310.70 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  23.86 (%)
#                   grid_import_energy:  991.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [32] Selected BESS Action -> discharge-500
#
#
#             [32] Current BESS Discharge Savings:  2500.00
#
#
#             [32] Future BESS Charge Cost:  833.33
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  50.00
#
#
#             [32] BESS SoC Reward:  0.00
#
#
#           [32] Calculated Reward ->  1666.670
#
#
#             [33] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  496.26
#                     Solar Full Production Energy:  496.26
#                     Solar Surplus Production Energy:  0.00
#
#
#           [33] Environment State ->
#                   hour_sin:  0.4121
#                   hour_cos: -0.9111
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1350.16 (kWh)
#                   solar_prod_energy:  496.26 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  36.76 (%)
#                   grid_import_energy:  853.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1500.00 (kWh)
#                   bess_soc:  50.00
#                   done: False
#
#
#           [33] Selected BESS Action -> charge-500
#
#
#             [33] Current BESS Charge Cost:  1000.00
#
#
#             [33] Future BESS Discharge Savings:  1350.00
#
#
#             [33] BESS SoC Reward:  0.00
#
#
#           [33] Calculated Reward ->  350.000
#
#
#             [34] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  969.00
#                     Solar Full Production Energy:  969.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [34] Environment State ->
#                   hour_sin: -0.5440
#                   hour_cos: -0.8391
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1295.30 (kWh)
#                   solar_prod_energy:  969.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  74.81 (%)
# ...
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  560.51 (kWh)
#                   solar_prod_energy:  313.11 (kWh)
#                   solar_ctlr_setpoint:  80.21 (%)
#                   solar_vs_load_ratio:  55.86 (%)
#                   grid_import_energy:  247.40 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [155] Selected BESS Action -> do-nothing
#
#
#             [155] BESS SoC Reward:  1000.00
#
#
#           [155] Calculated Reward ->  1000.000
#
#
#             [156] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.82
#                     Solar Production Energy:  227.76
#                     Solar Full Production Energy:  276.62
#                     Solar Surplus Production Energy:  48.86
#
#
#           [156] Environment State ->
#                   hour_sin: -0.5366
#                   hour_cos:  0.8439
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  540.66 (kWh)
#                   solar_prod_energy:  227.76 (kWh)
#                   solar_ctlr_setpoint:  82.34 (%)
#                   solar_vs_load_ratio:  42.13 (%)
#                   grid_import_energy:  312.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [156] Selected BESS Action -> do-nothing
#
#
#             [156] BESS SoC Reward:  1000.00
#
#
#           [156] Calculated Reward ->  1000.000
#
#
#             [157] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.92
#                     Solar Production Energy:  241.90
#                     Solar Full Production Energy:  263.96
#                     Solar Surplus Production Energy:  22.06
#
#
#           [157] Environment State ->
#                   hour_sin:  0.4202
#                   hour_cos:  0.9074
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  583.50 (kWh)
#                   solar_prod_energy:  241.90 (kWh)
#                   solar_ctlr_setpoint:  91.64 (%)
#                   solar_vs_load_ratio:  41.46 (%)
#                   grid_import_energy:  341.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [157] Selected BESS Action -> do-nothing
#
#
#             [157] BESS SoC Reward:  1000.00
#
#
#           [157] Calculated Reward ->  1000.000
#
#
#             [158] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.97
#                     Solar Production Energy:  19.73
#                     Solar Full Production Energy:  20.31
#                     Solar Surplus Production Energy:  0.58
#
#
#           [158] Environment State ->
#                   hour_sin:  0.9906
#                   hour_cos:  0.1367
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  563.63 (kWh)
#                   solar_prod_energy:  19.73 (kWh)
#                   solar_ctlr_setpoint:  97.15 (%)
#                   solar_vs_load_ratio:  3.50 (%)
#                   grid_import_energy:  543.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [158] Selected BESS Action -> do-nothing
#
#
#             [158] BESS SoC Reward:  1000.00
#
#
#           [158] Calculated Reward ->  1000.000
#
#
#             [159] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  1.18
#                     Solar Full Production Energy:  1.18
#                     Solar Surplus Production Energy:  0.00
#
#
#           [159] Environment State ->
#                   hour_sin:  0.6503
#                   hour_cos: -0.7597
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  574.48 (kWh)
#                   solar_prod_energy:  1.18 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.21 (%)
#                   grid_import_energy:  573.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [159] Selected BESS Action -> do-nothing
#
#
#             [159] BESS SoC Reward:  1000.00
#
#
#           [159] Calculated Reward ->  1000.000
#
#
#             [160] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.01
#                     Solar Full Production Energy:  0.01
#                     Solar Surplus Production Energy:  0.00
#
#
#           [160] Environment State ->
#                   hour_sin: -0.2879
#                   hour_cos: -0.9577
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  548.31 (kWh)
#                   solar_prod_energy:  0.01 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  548.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [160] Selected BESS Action -> do-nothing
#
#
#             [160] BESS SoC Reward:  1000.00
#
#
#           [160] Calculated Reward ->  1000.000
#
#
#             [161] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [161] Environment State ->
#                   hour_sin: -0.9614
#                   hour_cos: -0.2752
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  612.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  612.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [161] Selected BESS Action -> do-nothing
#
#
#             [161] BESS SoC Reward:  1000.00
#
#
#           [161] Calculated Reward ->  1000.000
#
#
#             [162] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [162] Environment State ->
#                   hour_sin: -0.7510
#                   hour_cos:  0.6603
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  639.60 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  639.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [162] Selected BESS Action -> do-nothing
#
#
#             [162] BESS SoC Reward:  1000.00
#
#
#           [162] Calculated Reward ->  1000.000
#
#
#             [163] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [163] Environment State ->
#                   hour_sin:  0.1499
#                   hour_cos:  0.9887
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  749.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  749.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [163] Selected BESS Action -> do-nothing
#
#
#             [163] BESS SoC Reward:  1000.00
#
#
#           [163] Calculated Reward ->  1000.000
#
#
#             [164] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [164] Environment State ->
#                   hour_sin:  0.9129
#                   hour_cos:  0.4081
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  969.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  969.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [164] Selected BESS Action -> do-nothing
#
#
#             [164] BESS SoC Reward:  1000.00
#
#
#           [164] Calculated Reward ->  1000.000
#
#
#             [165] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [165] Environment State ->
#                   hour_sin:  0.8367
#                   hour_cos: -0.5477
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1375.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1375.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [165] Selected BESS Action -> do-nothing
#
#
#             [165] BESS SoC Reward:  1000.00
#
#
#           [165] Calculated Reward ->  1000.000
#
#
#             [166] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [166] Environment State ->
#                   hour_sin: -0.0089
#                   hour_cos: -1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1130.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1130.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [166] Selected BESS Action -> do-nothing
#
#
#             [166] BESS SoC Reward:  1000.00
#
#
#           [166] Calculated Reward ->  1000.000
#
#
#             [167] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [167] Environment State ->
#                   hour_sin: -0.8462
#                   hour_cos: -0.5328
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1120.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1120.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [167] Selected BESS Action -> do-nothing
#
#
#             [167] BESS SoC Reward:  1000.00
#
#
#           [167] Calculated Reward ->  1000.000
#
# Episode terminal state reached !

# %%
print(f"Episode reward: {episode_reward: .2f}")

# Episode reward (optimal):  89.30, 90.96, 101.69, 118.74, 122.29
# Episode reward (sub-optimal):  76.62,
# Out:
# Episode reward:  118.74

# %%
# # Fixed Policy

# episode_reward = 0

# state, reward, done = env.reset(index=3)


# # TOU OFF-PEAK
# # ==============================================================
# # hour:3 -> do-nothing -> rw: 3:1000, 0:1000, 6:-3308
# state, reward, done = env.step(action=3)
# episode_reward += reward

# # hour:4 -> charge -> rw: 
# state, reward, done = env.step(action=3)
# episode_reward += reward

# # hour:5 -> charge -> rw: 
# state, reward, done = env.step(action=3)
# episode_reward += reward


# # TOU PEAK
# # ==============================================================
# # hour:6 -> discharge -> rw: 3:1000, 0:1000, 6:3846
# state, reward, done = env.step(action=6)
# episode_reward += reward

# # hour:7 -> discharge -> rw: 3:0, 0:-3212, 6:2241
# state, reward, done = env.step(action=6)
# episode_reward += reward

# # hour:8 -> discharge -> rw: 3:0, 0:-4583, 6:1436
# state, reward, done = env.step(action=0)
# episode_reward += reward


# # TOU STANDARD
# # ==============================================================
# # hour:9 -> do-nothing -> rw: 3:0, 0:1050, 6:-1145
# state, reward, done = env.step(action=0)
# episode_reward += reward

# # hour:10 -> do-nothing -> rw: 0
# state, reward, done = env.step(action=3)
# episode_reward += reward

# # hour:11 -> charge -> rw: 3:0, 0:806, 6:35
# state, reward, done = env.step(action=0)
# episode_reward += reward

# # hour:12 -> charge -> rw: 3:0, 0:1365, 6:37
# state, reward, done = env.step(action=6)
# episode_reward += reward

# # hour:13 -> charge -> rw: 3:0, 0:1000, 6:963
# state, reward, done = env.step(action=0)
# episode_reward += reward


# print(f"""
# Episode Reward: {episode_reward: .2f}
# """)

# # Episode reward (optimal policy): 14981.45 (9789.63)
