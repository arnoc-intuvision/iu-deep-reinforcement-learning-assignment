# %% [markdown]
# ### Import Library Dependencies

# %%
import os
import sys
import traceback
import logging as log
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from microgrid_env import MicrogridEnv
from q_learning_agent import QLearningAgent
from torch.utils.tensorboard.writer import SummaryWriter

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', None)

log.basicConfig(format="Line:%(lineno)d-%(funcName)s-%(levelname)s:  %(message)s")
log.getLogger().setLevel(log.INFO)

# %% [markdown]
# ### Environment Data Pre-processing

# %%
df = pd.read_csv("load_profile_data_nov2024.csv", header=0)

# %%
df.head()
# Out:
#      entry_time weekday tou_time_slot  grid_import_energy  solar_prod_energy  \
# 0  11/1/24 0:00  Friday             o              1339.4                0.0
# 1  11/1/24 1:00  Friday             o              1388.9                0.0
# 2  11/1/24 2:00  Friday             o              1444.8                0.0
# 3  11/1/24 3:00  Friday             o              1463.7                0.0
# 4  11/1/24 4:00  Friday             o              1467.0                0.0
#
#    solar_ctlr_setpoint  site_load_energy
# 0                100.0            1339.4
# 1                100.0            1388.9
# 2                100.0            1444.8
# 3                100.0            1463.7
# 4                100.0            1467.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   entry_time           720 non-null    object
#  1   weekday              720 non-null    object
#  2   tou_time_slot        720 non-null    object
#  3   grid_import_energy   720 non-null    float64
#  4   solar_prod_energy    720 non-null    float64
#  5   solar_ctlr_setpoint  720 non-null    float64
#  6   site_load_energy     720 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 39.5+ KB

# %%
df['timestamp'] = pd.to_datetime(df['entry_time'], format="mixed")

# %%
df['ts_hour'] = df['timestamp'].dt.hour

# %%
def convert_weekday(wkd: str) -> str:
    if wkd in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']:
        return 'week'
    else:
        return wkd.lower()

# %%
# One-hot encode the Weekday field
df['weekday_fmt'] = df['weekday'].map(lambda wkd: convert_weekday(wkd))
df['day_week'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'week' else 0)
df['day_saturday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'saturday' else 0)
df['day_sunday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'sunday' else 0)

# %%
# One-hot encode the TOU Timeslot field
df['tou_offpeak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'o' else 0)
df['tou_standard'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 's' else 0)
df['tou_peak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'p' else 0)

# %%
# Convert hour field to unit circle coordinates
df['ts_hour_sin'] = np.sin( df['ts_hour'] )
df['ts_hour_cos'] = np.cos( df['ts_hour'] )

# %%
df.set_index('timestamp', inplace=True)

# %%
df.drop(['entry_time', 'ts_hour', 'weekday', 'weekday_fmt', 'tou_time_slot'], axis=1, inplace=True)

# %%
load_profile_df = df[['ts_hour_sin', 'ts_hour_cos', 'tou_offpeak', 'tou_standard', 'tou_peak', 'day_week', 'day_saturday', 'day_sunday', 'site_load_energy', 'solar_prod_energy', 'solar_ctlr_setpoint', 'grid_import_energy']]

# %%
load_profile_df.head(48)
# Out:
#                      ts_hour_sin  ts_hour_cos  tou_offpeak  tou_standard  \
# timestamp
# 2024-11-02 09:00:00                68.8
# 2024-11-02 10:00:00                68.5
# 2024-11-02 11:00:00                71.8
# 2024-11-02 12:00:00                68.7
# 2024-11-02 13:00:00                71.1
# 2024-11-02 14:00:00                67.7
# 2024-11-02 15:00:00                68.4
# 2024-11-02 16:00:00               234.6
# 2024-11-02 17:00:00               559.2
# 2024-11-02 18:00:00               684.0
# 2024-11-02 19:00:00               700.1
# 2024-11-02 20:00:00               729.5
# 2024-11-02 21:00:00               631.4
# 2024-11-02 22:00:00               641.7
# 2024-11-02 23:00:00               603.4

# %%
load_profile_df.describe().T
# Out:
#                      count         mean         std       min          25%  \
# ts_hour_sin          720.0     0.040825    0.697899 -0.999990    -0.595763
# ts_hour_cos          720.0    -0.022538    0.715646 -0.999961    -0.680155
# tou_offpeak          720.0     0.443056    0.497092  0.000000     0.000000
# tou_standard         720.0     0.411111    0.492377  0.000000     0.000000
# tou_peak             720.0     0.145833    0.353184  0.000000     0.000000
# day_week             720.0     0.700000    0.458576  0.000000     0.000000
# day_saturday         720.0     0.166667    0.372937  0.000000     0.000000
# day_sunday           720.0     0.133333    0.340171  0.000000     0.000000
# site_load_energy     720.0  1243.478583  327.529219  0.000000  1063.915000
# solar_prod_energy    720.0   306.043861  414.502550  0.000000     0.000000
# solar_ctlr_setpoint  720.0    96.577807   11.593107  0.100000   100.000000
# grid_import_energy   720.0   937.434722  469.967471  0.000000   573.000000
#
#                              50%          75%          max
# ts_hour_sin             0.070560     0.701904     0.990607
# ts_hour_cos            -0.070537     0.683713     1.000000
# tou_offpeak             0.000000     1.000000     1.000000
# tou_standard            0.000000     1.000000     1.000000
# tou_peak                0.000000     0.000000     1.000000
# day_week                1.000000     1.000000     1.000000
# day_saturday            0.000000     0.000000     1.000000
# day_sunday              0.000000     0.000000     1.000000
# site_load_energy     1322.400000  1488.250000  1934.700000
# solar_prod_energy      36.000000   561.375000  1443.100000
# solar_ctlr_setpoint   100.000000   100.000000   100.000000
# grid_import_energy   1027.250000  1329.825000  1934.700000

# %%
# Filter the load profile data for a specific date period
load_profile_filtered_df = load_profile_df.loc['2024-11-04':'2024-11-10']

# %%
load_profile_filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2024-11-04 00:00:00 to 2024-11-10 23:00:00
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ts_hour_sin          168 non-null    float64
#  1   ts_hour_cos          168 non-null    float64
#  2   tou_offpeak          168 non-null    int64
#  3   tou_standard         168 non-null    int64
#  4   tou_peak             168 non-null    int64
#  5   day_week             168 non-null    int64
#  6   day_saturday         168 non-null    int64
#  7   day_sunday           168 non-null    int64
#  8   site_load_energy     168 non-null    float64
#  9   solar_prod_energy    168 non-null    float64
#  10  solar_ctlr_setpoint  168 non-null    float64
#  11  grid_import_energy   168 non-null    float64
# dtypes: float64(6), int64(6)
# memory usage: 17.1 KB

# %% [markdown]
# ### Train Q-Learning Agent

# %%
best_reward = -999_999

daily_episode_reward = 0.0
daily_episode_memory = []

weekly_episode_reward = 0.0
weekly_episode_memory = []

mini_flex_high_demand_tariff = {'peak_rate': 624.05, 'standard_rate': 189.08, 'offpeak_rate': 102.70}
mini_flex_low_demand_tariff = {'peak_rate': 203.57, 'standard_rate': 140.10, 'offpeak_rate': 88.91}

selected_tariff = mini_flex_high_demand_tariff

env = MicrogridEnv(data = load_profile_filtered_df, 
                   grid_notified_maximum_demand = 2000.0, 
                   bess_capacity = 3000.0, 
                   bess_cycle_efficiency = 0.9, 
                   bess_step_sizes = [1500.0, 1000.0, 500.0, 0.0, 500.0, 1000.0, 1500.0], 
                   tou_peak_tariff = selected_tariff['peak_rate'] / 100.0, 
                   tou_standard_tariff = selected_tariff['standard_rate'] / 100.0, 
                   tou_offpeak_tariff = selected_tariff['offpeak_rate'] / 100.0, 
                   solar_ppa_tariff = 1.4,
                   debug_flag = False)

total_num_steps = 168*10_000

agent = QLearningAgent(env=env, 
                       discounting_factor=0.99,
                       learning_rate=0.05,
                       epsilon_start = 1.0, 
                       epsilon_end = 0.01, 
                       decay_steps = total_num_steps)

iter_no = 1

while True:
    
    iter_no += 1

    # Take one step in the environment
    state, action, reward, next_state = agent.sample_env(use_fixed_rule_policy=False)

    # Hourly q-value update
    agent.value_update(state.index, action, reward, next_state.index)

    daily_episode_reward += reward
    daily_episode_memory.append( (state, action, reward, next_state) )
    
    weekly_episode_reward += reward
    weekly_episode_memory.append( (state, action, reward, next_state) )

    if (iter_no % 24) == 0:

        # print(f"[{iter_no}] daily episode reward: {daily_episode_reward: .2f}")

        # Daily q-value update
        # for state_d, action_d, reward_d, next_state_d in daily_episode_memory:
        #     agent.value_update(state_d.index, action_d, daily_episode_reward, next_state_d.index)

        daily_episode_reward = 0.0
        daily_episode_memory = []
        
        if (iter_no % 168) == 0:
    
            # print(f"[{iter_no}] weekly episode reward: {weekly_episode_reward: .2f}")

            # Weekly q-value update
            # for state_w, action_w, reward_w, next_state_w in weekly_episode_memory:
            #     agent.value_update(state_w.index, action_w, weekly_episode_reward, next_state_w.index)
    
            if weekly_episode_reward > best_reward:
                print(f"[{iter_no}] Best weekly episode reward updated {best_reward: .3f} -> {weekly_episode_reward: .3f}")
                best_reward = weekly_episode_reward
    
            if (best_reward > 120) or (iter_no >= total_num_steps):

                print("\nDone !!!\n")

                print(f"\nSolved in {iter_no} iterations !\n")
    
                print(f"\nBest weekly episode reward: {best_reward: .2f}\n")
                
                test_env = MicrogridEnv(data = load_profile_filtered_df, 
                                        grid_notified_maximum_demand = 2000.0, 
                                        bess_capacity = 3000.0, 
                                        bess_cycle_efficiency = 0.9, 
                                        bess_step_sizes = [1500.0, 1000.0, 500.0, 0.0, 500.0, 1000.0, 1500.0], 
                                        tou_peak_tariff = selected_tariff['peak_rate'] / 100.0, 
                                        tou_standard_tariff = selected_tariff['standard_rate'] / 100.0, 
                                        tou_offpeak_tariff = selected_tariff['offpeak_rate'] / 100.0, 
                                        solar_ppa_tariff = 1.4,
                                        debug_flag = True)
    
                agent.save_learned_policy(env=test_env)

                break
    
            weekly_episode_reward = 0.0
            weekly_episode_memory = []
# Out:
# [168] Best weekly episode reward updated -999999.000 -> -37.209
# [2184] Best weekly episode reward updated -37.209 -> -35.776
# [3696] Best weekly episode reward updated -35.776 -> -24.189
# [15624] Best weekly episode reward updated -24.189 -> -20.282
# [20160] Best weekly episode reward updated -20.282 -> -16.024
# [74928] Best weekly episode reward updated -16.024 -> -12.228
# [93576] Best weekly episode reward updated -12.228 -> -10.678
# [188328] Best weekly episode reward updated -10.678 ->  7.367
# [563808] Best weekly episode reward updated  7.367 ->  18.992
# [581784] Best weekly episode reward updated  18.992 ->  25.131
# [598920] Best weekly episode reward updated  25.131 ->  33.090
# [639744] Best weekly episode reward updated  33.090 ->  37.734
# [658896] Best weekly episode reward updated  37.734 ->  40.459
# [803376] Best weekly episode reward updated  40.459 ->  43.843
# [965160] Best weekly episode reward updated  43.843 ->  44.894
# [1020264] Best weekly episode reward updated  44.894 ->  50.379
# [1171632] Best weekly episode reward updated  50.379 ->  50.520
# [1185576] Best weekly episode reward updated  50.520 ->  59.389
# [1338120] Best weekly episode reward updated  59.389 ->  65.678
#
# Done !!!
#
#
# Solved in 1680000 iterations !
#
#
# Best weekly episode reward:  65.68
#
# Environment Defaults:
#
#           Grid Notified Maximum Demand: 2000.0 kVA
#           BESS Capacity: 3000.0 kWh
#           BESS Actions: charge-1500, charge-1000, charge-500, do-nothing, discharge-500, discharge-1000, discharge-1500
#
#
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2024-11-04 00:00:00 to 2024-11-10 23:00:00
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ts_hour_sin          168 non-null    float64
#  1   ts_hour_cos          168 non-null    float64
#  2   tou_offpeak          168 non-null    int64
#  3   tou_standard         168 non-null    int64
#  4   tou_peak             168 non-null    int64
#  5   day_week             168 non-null    int64
#  6   day_saturday         168 non-null    int64
#  7   day_sunday           168 non-null    int64
#  8   site_load_energy     168 non-null    float64
#  9   solar_prod_energy    168 non-null    float64
#  10  solar_ctlr_setpoint  168 non-null    float64
#  11  grid_import_energy   168 non-null    float64
# dtypes: float64(6), int64(6)
# memory usage: 17.1 KB
# None
#
#
#
#             [0] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [0] Environment State ->
#                   hour_sin:  0.0000
#                   hour_cos:  1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1031.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1031.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [0] Selected BESS Action -> discharge-1500
#
#
#             [0] Current BESS Discharge Savings:  1059.76
#
#
#             [0] Future BESS Charge Cost:  4661.49
#                            BESS Grid Charge Energy:  1146.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  65.60
#
#
#             [0] BESS SoC Reward:  0.00
#
#
#           [0] Calculated Reward -> -3601.730
#
#
#             [1] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [1] Environment State ->
#                   hour_sin:  0.8415
#                   hour_cos:  0.5403
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1191.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1191.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1968.10 (kWh)
#                   bess_soc:  65.60
#                   done: False
#
#
#           [1] Selected BESS Action -> charge-1000
#
#
#             [1] Current BESS Charge Cost:  830.74
#
#
#             [1] Future BESS Discharge Savings:  2959.83
#
#
#             [1] BESS SoC Reward: -925.70
#
#
#           [1] Calculated Reward ->  1203.390
#
#
#             [2] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [2] Environment State ->
#                   hour_sin:  0.9093
#                   hour_cos: -0.4161
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1233.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1233.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2777.00 (kWh)
#                   bess_soc:  92.57
#                   done: False
#
#
#           [2] Selected BESS Action -> do-nothing
#
#
#             [2] BESS SoC Reward:  925.70
#
#
#           [2] Calculated Reward ->  925.700
#
#
#             [3] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [3] Environment State ->
#                   hour_sin:  0.1411
#                   hour_cos: -0.9900
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1145.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1145.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2777.00 (kWh)
#                   bess_soc:  92.57
#                   done: False
#
#
#           [3] Selected BESS Action -> do-nothing
#
#
#             [3] BESS SoC Reward:  925.70
#
#
#           [3] Calculated Reward ->  925.700
#
#
#             [4] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [4] Environment State ->
#                   hour_sin: -0.7568
#                   hour_cos: -0.6536
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1247.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1247.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2777.00 (kWh)
#                   bess_soc:  92.57
#                   done: False
#
#
#           [4] Selected BESS Action -> charge-1000
#
#
#             [4] Current BESS Charge Cost:  229.02
#
#
#             [4] Future BESS Discharge Savings:  815.98
#
#
#             [4] BESS SoC Reward: -1000.00
#
#
#           [4] Calculated Reward -> -413.040
#
#
#             [5] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  30.52
#                     Solar Full Production Energy:  30.52
#                     Solar Surplus Production Energy:  0.00
#
#
#           [5] Environment State ->
#                   hour_sin: -0.9589
#                   hour_cos:  0.2837
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1356.72 (kWh)
#                   solar_prod_energy:  30.52 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  2.25 (%)
#                   grid_import_energy:  1326.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [5] Selected BESS Action -> charge-500
#
#
#             [5] Current BESS Charge Cost:  0.00
#
#
#             [5] Future BESS Discharge Savings:  0.00
#
#
#             [5] BESS SoC Reward: -1000.00
#
#
#           [5] Calculated Reward -> -1000.000
#
#
#             [6] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  186.90
#                     Solar Full Production Energy:  186.90
#                     Solar Surplus Production Energy:  0.00
#
#
#           [6] Environment State ->
#                   hour_sin: -0.2794
#                   hour_cos:  0.9602
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1340.90 (kWh)
#                   solar_prod_energy:  186.90 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  13.94 (%)
#                   grid_import_energy:  1154.00 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [6] Selected BESS Action -> discharge-1500
#
#
#             [6] Current BESS Discharge Savings:  7201.54
#
#
#             [6] Future BESS Charge Cost:  1870.63
#                            BESS Grid Charge Energy:  1282.22
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  61.53
#
#
#             [6] BESS SoC Reward:  0.00
#
#
#           [6] Calculated Reward ->  5330.910
#
#
#             [7] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  545.90
#                     Solar Full Production Energy:  545.90
#                     Solar Surplus Production Energy:  0.00
#
#
#           [7] Environment State ->
#                   hour_sin:  0.6570
#                   hour_cos:  0.7539
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1218.30 (kWh)
#                   solar_prod_energy:  545.90 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  44.81 (%)
#                   grid_import_energy:  672.40 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1846.00 (kWh)
#                   bess_soc:  61.53
#                   done: False
#
#
#           [7] Selected BESS Action -> discharge-500
#
#
#             [7] Current BESS Discharge Savings:  3120.25
#
#
#             [7] Future BESS Charge Cost:  810.50
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  44.87
#
#
#             [7] BESS SoC Reward:  0.00
#
#
#           [7] Calculated Reward ->  2309.750
#
#
#             [8] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  832.30
#                     Solar Full Production Energy:  832.30
#                     Solar Surplus Production Energy:  0.00
#
#
#           [8] Environment State ->
#                   hour_sin:  0.9894
#                   hour_cos: -0.1455
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1263.20 (kWh)
#                   solar_prod_energy:  832.30 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  65.89 (%)
#                   grid_import_energy:  430.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1346.00 (kWh)
#                   bess_soc:  44.87
#                   done: False
#
#
#           [8] Selected BESS Action -> discharge-1500
#
#
#             [8] Current BESS Discharge Savings:  2689.03
#
#
#             [8] Future BESS Charge Cost:  698.49
#                            BESS Grid Charge Energy:  478.78
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  30.50
#
#
#             [8] BESS SoC Reward:  0.00
#
#
#           [8] Calculated Reward ->  1990.540
#
#
#             [9] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  1123.60
#                     Solar Full Production Energy:  1123.60
#                     Solar Surplus Production Energy:  0.00
#
#
#           [9] Environment State ->
#                   hour_sin:  0.4121
#                   hour_cos: -0.9111
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1359.30 (kWh)
#                   solar_prod_energy:  1123.60 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  82.66 (%)
#                   grid_import_energy:  235.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  915.10 (kWh)
#                   bess_soc:  30.50
#                   done: False
#
#
#           [9] Selected BESS Action -> discharge-1500
#
#
#             [9] Current BESS Discharge Savings:  445.66
#
#
#             [9] Future BESS Charge Cost:  951.64
#                            BESS Grid Charge Energy:  261.89
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  22.65
#
#
#             [9] BESS SoC Reward:  0.00
#
#
#           [9] Calculated Reward -> -505.980
#
#
#             [10] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.94
#                     Solar Production Energy:  1198.20
#                     Solar Full Production Energy:  1270.59
#                     Solar Surplus Production Energy:  72.39
#
#
#           [10] Environment State ->
#                   hour_sin: -0.5440
#                   hour_cos: -0.8391
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1272.70 (kWh)
#                   solar_prod_energy:  1198.20 (kWh)
#                   solar_ctlr_setpoint:  94.30 (%)
#                   solar_vs_load_ratio:  94.15 (%)
#                   grid_import_energy:  74.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  679.40 (kWh)
#                   bess_soc:  22.65
#                   done: False
#
#
#           [10] Selected BESS Action -> discharge-500
#
#
#             [10] Current BESS Discharge Savings:  140.86
#
#
#             [10] Future BESS Charge Cost:  139.09
#                            BESS Grid Charge Energy:  10.39
#                            BESS Solar Charge Energy:  72.39
#                            BESS SoC:  20.16
#
#
#             [10] BESS SoC Reward:  0.00
#
#
#           [10] Calculated Reward ->  1.770
#
#
#             [11] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.79
#                     Solar Production Energy:  1114.00
#                     Solar Full Production Energy:  1404.03
#                     Solar Surplus Production Energy:  290.03
#
#
#           [11] Environment State ->
#                   hour_sin: -1.0000
#                   hour_cos:  0.0044
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1194.60 (kWh)
#                   solar_prod_energy:  1114.00 (kWh)
#                   solar_ctlr_setpoint:  79.34 (%)
#                   solar_vs_load_ratio:  93.25 (%)
#                   grid_import_energy:  80.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  604.90 (kWh)
#                   bess_soc:  20.16
#                   done: False
#
#
#           [11] Selected BESS Action -> discharge-500
#
#
#             [11] Current BESS Discharge Savings:  152.40
#
#
#             [11] Future BESS Charge Cost:  125.38
#                            BESS Grid Charge Energy:  0.00
#                            BESS Solar Charge Energy:  89.56
#                            BESS SoC:  17.48
#
#
#             [11] BESS SoC Reward: -825.20
#
#
#           [11] Calculated Reward -> -798.180
#
#
#             [12] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.76
#                     Solar Production Energy:  1212.70
#                     Solar Full Production Energy:  1601.37
#                     Solar Surplus Production Energy:  388.67
#
#
#           [12] Environment State ->
#                   hour_sin: -0.5366
#                   hour_cos:  0.8439
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1296.00 (kWh)
#                   solar_prod_energy:  1212.70 (kWh)
#                   solar_ctlr_setpoint:  75.73 (%)
#                   solar_vs_load_ratio:  93.57 (%)
#                   grid_import_energy:  83.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  524.30 (kWh)
#                   bess_soc:  17.48
#                   done: False
#
#
#           [12] Selected BESS Action -> discharge-1500
#
#
#             [12] Current BESS Discharge Savings:  157.50
#
#
#             [12] Future BESS Charge Cost:  129.58
#                            BESS Grid Charge Energy:  0.00
#                            BESS Solar Charge Energy:  92.56
#                            BESS SoC:  14.70
#
#
#             [12] BESS SoC Reward: -853.00
#
#
#           [12] Calculated Reward -> -825.080
#
#
#             [13] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.81
#                     Solar Production Energy:  984.30
#                     Solar Full Production Energy:  1211.00
#                     Solar Surplus Production Energy:  226.70
#
#
#           [13] Environment State ->
#                   hour_sin:  0.4202
#                   hour_cos:  0.9074
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1223.80 (kWh)
#                   solar_prod_energy:  984.30 (kWh)
#                   solar_ctlr_setpoint:  81.28 (%)
#                   solar_vs_load_ratio:  80.43 (%)
#                   grid_import_energy:  239.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  441.00 (kWh)
#                   bess_soc:  14.70
#                   done: False
#
#
#           [13] Selected BESS Action -> charge-1500
#
#
#             [13] Current BESS Charge Cost:  2724.94
#
#
#             [13] Future BESS Discharge Savings:  4449.81
#
#
#             [13] BESS SoC Reward:  0.00
#
#
#           [13] Calculated Reward ->  1724.870
#
#
#             [14] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.84
#                     Solar Production Energy:  885.20
#                     Solar Full Production Energy:  1058.74
#                     Solar Surplus Production Energy:  173.54
#
#
#           [14] Environment State ->
#                   hour_sin:  0.9906
#                   hour_cos:  0.1367
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1216.00 (kWh)
#                   solar_prod_energy:  885.20 (kWh)
#                   solar_ctlr_setpoint:  83.61 (%)
#                   solar_vs_load_ratio:  72.80 (%)
#                   grid_import_energy:  330.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1941.00 (kWh)
#                   bess_soc:  64.70
#                   done: False
#
#
#           [14] Selected BESS Action -> discharge-500
#
#
#             [14] Current BESS Discharge Savings:  625.48
#
#
#             [14] Future BESS Charge Cost:  947.96
#                            BESS Grid Charge Energy:  194.02
#                            BESS Solar Charge Energy:  173.54
#                            BESS SoC:  53.67
#
#
#             [14] BESS SoC Reward:  0.00
#
#
#           [14] Calculated Reward -> -322.480
#
#
#             [15] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.93
#                     Solar Production Energy:  689.90
#                     Solar Full Production Energy:  741.58
#                     Solar Surplus Production Energy:  51.68
#
#
#           [15] Environment State ->
#                   hour_sin:  0.6503
#                   hour_cos: -0.7597
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1133.50 (kWh)
#                   solar_prod_energy:  689.90 (kWh)
#                   solar_ctlr_setpoint:  93.03 (%)
#                   solar_vs_load_ratio:  60.86 (%)
#                   grid_import_energy:  443.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1610.20 (kWh)
#                   bess_soc:  53.67
#                   done: False
#
#
#           [15] Selected BESS Action -> charge-500
#
#
#             [15] Current BESS Charge Cost:  920.04
#
#
#             [15] Future BESS Discharge Savings:  1531.29
#
#
#             [15] BESS SoC Reward:  0.00
#
#
#           [15] Calculated Reward ->  611.250
#
#
#             [16] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.98
#                     Solar Production Energy:  286.90
#                     Solar Full Production Energy:  292.94
#                     Solar Surplus Production Energy:  6.04
#
#
#           [16] Environment State ->
#                   hour_sin: -0.2879
#                   hour_cos: -0.9577
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1051.50 (kWh)
#                   solar_prod_energy:  286.90 (kWh)
#                   solar_ctlr_setpoint:  97.94 (%)
#                   solar_vs_load_ratio:  27.28 (%)
#                   grid_import_energy:  764.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2110.20 (kWh)
#                   bess_soc:  70.34
#                   done: False
#
#
#           [16] Selected BESS Action -> charge-1000
#
#
#             [16] Current BESS Charge Cost:  1679.80
#
#
#             [16] Future BESS Discharge Savings:  2899.18
#
#
#             [16] BESS SoC Reward: -1000.00
#
#
#           [16] Calculated Reward ->  219.380
#
#
#             [17] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  109.30
#                     Solar Full Production Energy:  109.30
#                     Solar Surplus Production Energy:  0.00
#
#
#           [17] Environment State ->
#                   hour_sin: -0.9614
#                   hour_cos: -0.2752
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1337.10 (kWh)
#                   solar_prod_energy:  109.30 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  8.17 (%)
#                   grid_import_energy:  1227.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [17] Selected BESS Action -> discharge-1000
#
#
#             [17] Current BESS Discharge Savings:  6240.50
#
#
#             [17] Future BESS Charge Cost:  1621.00
#                            BESS Grid Charge Energy:  1111.11
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  66.67
#
#
#             [17] BESS SoC Reward:  0.00
#
#
#           [17] Calculated Reward ->  4619.500
#
#
#             [18] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  30.26
#                     Solar Full Production Energy:  30.26
#                     Solar Surplus Production Energy:  0.00
#
#
#           [18] Environment State ->
#                   hour_sin: -0.7510
#                   hour_cos:  0.6603
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1117.86 (kWh)
#                   solar_prod_energy:  30.26 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  2.71 (%)
#                   grid_import_energy:  1087.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [18] Selected BESS Action -> discharge-500
#
#
#             [18] Current BESS Discharge Savings:  3120.25
#
#
#             [18] Future BESS Charge Cost:  810.50
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  50.00
#
#
#             [18] BESS SoC Reward:  0.00
#
#
#           [18] Calculated Reward ->  2309.750
#
#
#             [19] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [19] Environment State ->
#                   hour_sin:  0.1499
#                   hour_cos:  0.9887
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1082.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1082.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  1500.00 (kWh)
#                   bess_soc:  50.00
#                   done: False
#
#
#           [19] Selected BESS Action -> charge-500
#
#
#             [19] Current BESS Charge Cost:  945.40
#
#
#             [19] Future BESS Discharge Savings:  1635.19
#
#
#             [19] BESS SoC Reward:  0.00
#
#
#           [19] Calculated Reward ->  689.790
#
#
#             [20] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [20] Environment State ->
#                   hour_sin:  0.9129
#                   hour_cos:  0.4081
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1139.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1139.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [20] Selected BESS Action -> do-nothing
#
#
#             [20] BESS SoC Reward:  0.00
#
#
#           [20] Calculated Reward ->  0.000
#
#
#             [21] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [21] Environment State ->
#                   hour_sin:  0.8367
#                   hour_cos: -0.5477
#                   tou_offpeak:  0
#                   tou_standard:  1
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1074.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1074.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2000.00 (kWh)
#                   bess_soc:  66.67
#                   done: False
#
#
#           [21] Selected BESS Action -> charge-1500
#
#
#             [21] Current BESS Charge Cost:  1750.69
#
#
#             [21] Future BESS Discharge Savings:  3028.04
#
#
#             [21] BESS SoC Reward: -975.30
#
#
#           [21] Calculated Reward ->  302.050
#
#
#             [22] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [22] Environment State ->
#                   hour_sin: -0.0089
#                   hour_cos: -1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1126.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1126.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2925.90 (kWh)
#                   bess_soc:  97.53
#                   done: False
#
#
#           [22] Selected BESS Action -> charge-1500
#
#
#             [22] Current BESS Charge Cost:  76.10
#
#
#             [22] Future BESS Discharge Savings:  271.14
#
#
#             [22] BESS SoC Reward: -1000.00
#
#
#           [22] Calculated Reward -> -804.960
#
#
#             [23] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [23] Environment State ->
#                   hour_sin: -0.8462
#                   hour_cos: -0.5328
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1438.50 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1438.50 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [23] Selected BESS Action -> do-nothing
#
#
#             [23] BESS SoC Reward:  1000.00
#
#
#           [23] Calculated Reward ->  1000.000
#
#
#             [24] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [24] Environment State ->
#                   hour_sin:  0.0000
#                   hour_cos:  1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1255.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1255.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [24] Selected BESS Action -> discharge-500
#
#
#             [24] Current BESS Discharge Savings:  513.50
#
#
#             [24] Future BESS Charge Cost:  2258.69
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  83.33
#
#
#             [24] BESS SoC Reward:  833.30
#
#
#           [24] Calculated Reward -> -911.890
#
#
#             [25] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [25] Environment State ->
#                   hour_sin:  0.8415
#                   hour_cos:  0.5403
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1339.70 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1339.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [25] Selected BESS Action -> do-nothing
#
#
#             [25] BESS SoC Reward:  833.30
#
#
#           [25] Calculated Reward ->  833.300
#
#
#             [26] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [26] Environment State ->
#                   hour_sin:  0.9093
#                   hour_cos: -0.4161
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1292.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1292.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [26] Selected BESS Action -> do-nothing
#
#
#             [26] BESS SoC Reward:  833.30
#
#
#           [26] Calculated Reward ->  833.300
#
#
#             [27] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [27] Environment State ->
#                   hour_sin:  0.1411
#                   hour_cos: -0.9900
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1201.40 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1201.40 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [27] Selected BESS Action -> charge-1000
#
#
#             [27] Current BESS Charge Cost:  513.50
#
#
#             [27] Future BESS Discharge Savings:  1829.54
#
#
#             [27] BESS SoC Reward: -1000.00
#
#
#           [27] Calculated Reward ->  316.040
#
#
#             [28] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [28] Environment State ->
#                   hour_sin: -0.7568
#                   hour_cos: -0.6536
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1159.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1159.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [28] Selected BESS Action -> charge-1000
#
#
#             [28] Current BESS Charge Cost:  0.00
#
#
#             [28] Future BESS Discharge Savings:  0.00
#
#
#             [28] BESS SoC Reward: -1000.00
#
#
#           [28] Calculated Reward -> -1000.000
#
#
#             [29] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  10.97
#                     Solar Full Production Energy:  10.97
#                     Solar Surplus Production Energy:  0.00
#
#
#           [29] Environment State ->
#                   hour_sin: -0.9589
#                   hour_cos:  0.2837
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1147.87 (kWh)
#                   solar_prod_energy:  10.97 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.96 (%)
#                   grid_import_energy:  1136.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [29] Selected BESS Action -> charge-1000
#
#
#             [29] Current BESS Charge Cost:  0.00
#
#
#             [29] Future BESS Discharge Savings:  0.00
#
#
#             [29] BESS SoC Reward: -1000.00
#
#
#           [29] Calculated Reward -> -1000.000
#
#
#             [30] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  102.91
#                     Solar Full Production Energy:  102.91
#                     Solar Surplus Production Energy:  0.00
#
#
#           [30] Environment State ->
#                   hour_sin: -0.2794
#                   hour_cos:  0.9602
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1269.61 (kWh)
#                   solar_prod_energy:  102.91 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  8.11 (%)
#                   grid_import_energy:  1166.70 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [30] Selected BESS Action -> discharge-1500
#
#
#             [30] Current BESS Discharge Savings:  7280.79
#
#
#             [30] Future BESS Charge Cost:  1891.22
#                            BESS Grid Charge Energy:  1296.33
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  61.11
#
#
#             [30] BESS SoC Reward:  0.00
#
#
#           [30] Calculated Reward ->  5389.570
#
#
#             [31] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  212.85
#                     Solar Full Production Energy:  212.85
#                     Solar Surplus Production Energy:  0.00
#
#
#           [31] Environment State ->
#                   hour_sin:  0.6570
#                   hour_cos:  0.7539
#                   tou_offpeak:  0
#                   tou_standard:  0
#                   tou_peak:  1
#                   day_week:  1
#                   day_saturday:  0
#                   day_sunday:  0
#                   site_load_energy:  1284.45 (kWh)
#                   solar_prod_energy:  212.85 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  16.57 (%)
#                   grid_import_energy:  1071.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
# ...
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [156] Selected BESS Action -> discharge-500
#
#
#             [156] Current BESS Discharge Savings:  321.35
#
#
#             [156] Future BESS Charge Cost:  1283.25
#                            BESS Grid Charge Energy:  298.81
#                            BESS Solar Charge Energy:  48.86
#                            BESS SoC:  89.57
#
#
#             [156] BESS SoC Reward:  895.70
#
#
#           [156] Calculated Reward -> -66.200
#
#
#             [157] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.92
#                     Solar Production Energy:  241.90
#                     Solar Full Production Energy:  263.96
#                     Solar Surplus Production Energy:  22.06
#
#
#           [157] Environment State ->
#                   hour_sin:  0.4202
#                   hour_cos:  0.9074
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  583.50 (kWh)
#                   solar_prod_energy:  241.90 (kWh)
#                   solar_ctlr_setpoint:  91.64 (%)
#                   solar_vs_load_ratio:  41.46 (%)
#                   grid_import_energy:  341.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2687.10 (kWh)
#                   bess_soc:  89.57
#                   done: False
#
#
#           [157] Selected BESS Action -> discharge-1500
#
#
#             [157] Current BESS Discharge Savings:  350.82
#
#
#             [157] Future BESS Charge Cost:  1484.34
#                            BESS Grid Charge Energy:  357.50
#                            BESS Solar Charge Energy:  22.06
#                            BESS SoC:  78.18
#
#
#             [157] BESS SoC Reward:  0.00
#
#
#           [157] Calculated Reward -> -1133.520
#
#
#             [158] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  0.97
#                     Solar Production Energy:  19.73
#                     Solar Full Production Energy:  20.31
#                     Solar Surplus Production Energy:  0.58
#
#
#           [158] Environment State ->
#                   hour_sin:  0.9906
#                   hour_cos:  0.1367
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  563.63 (kWh)
#                   solar_prod_energy:  19.73 (kWh)
#                   solar_ctlr_setpoint:  97.15 (%)
#                   solar_vs_load_ratio:  3.50 (%)
#                   grid_import_energy:  543.90 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2345.50 (kWh)
#                   bess_soc:  78.18
#                   done: False
#
#
#           [158] Selected BESS Action -> charge-1500
#
#
#             [158] Current BESS Charge Cost:  672.27
#
#
#             [158] Future BESS Discharge Savings:  2394.25
#
#
#             [158] BESS SoC Reward: -1000.00
#
#
#           [158] Calculated Reward ->  721.980
#
#
#             [159] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  1.18
#                     Solar Full Production Energy:  1.18
#                     Solar Surplus Production Energy:  0.00
#
#
#           [159] Environment State ->
#                   hour_sin:  0.6503
#                   hour_cos: -0.7597
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  574.48 (kWh)
#                   solar_prod_energy:  1.18 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.21 (%)
#                   grid_import_energy:  573.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [159] Selected BESS Action -> do-nothing
#
#
#             [159] BESS SoC Reward:  1000.00
#
#
#           [159] Calculated Reward ->  1000.000
#
#
#             [160] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.01
#                     Solar Full Production Energy:  0.01
#                     Solar Surplus Production Energy:  0.00
#
#
#           [160] Environment State ->
#                   hour_sin: -0.2879
#                   hour_cos: -0.9577
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  548.31 (kWh)
#                   solar_prod_energy:  0.01 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  548.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [160] Selected BESS Action -> charge-500
#
#
#             [160] Current BESS Charge Cost:  0.00
#
#
#             [160] Future BESS Discharge Savings:  0.00
#
#
#             [160] BESS SoC Reward: -1000.00
#
#
#           [160] Calculated Reward -> -1000.000
#
#
#             [161] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [161] Environment State ->
#                   hour_sin: -0.9614
#                   hour_cos: -0.2752
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  612.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  612.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [161] Selected BESS Action -> discharge-500
#
#
#             [161] Current BESS Discharge Savings:  513.50
#
#
#             [161] Future BESS Charge Cost:  2258.69
#                            BESS Grid Charge Energy:  555.56
#                            BESS Solar Charge Energy:  0.00
#                            BESS SoC:  83.33
#
#
#             [161] BESS SoC Reward:  833.30
#
#
#           [161] Calculated Reward -> -911.890
#
#
#             [162] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [162] Environment State ->
#                   hour_sin: -0.7510
#                   hour_cos:  0.6603
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  639.60 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  639.60 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [162] Selected BESS Action -> do-nothing
#
#
#             [162] BESS SoC Reward:  833.30
#
#
#           [162] Calculated Reward ->  833.300
#
#
#             [163] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [163] Environment State ->
#                   hour_sin:  0.1499
#                   hour_cos:  0.9887
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  749.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  749.20 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  2500.00 (kWh)
#                   bess_soc:  83.33
#                   done: False
#
#
#           [163] Selected BESS Action -> charge-500
#
#
#             [163] Current BESS Charge Cost:  513.50
#
#
#             [163] Future BESS Discharge Savings:  1829.54
#
#
#             [163] BESS SoC Reward: -1000.00
#
#
#           [163] Calculated Reward ->  316.040
#
#
#             [164] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [164] Environment State ->
#                   hour_sin:  0.9129
#                   hour_cos:  0.4081
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  969.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  969.10 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [164] Selected BESS Action -> do-nothing
#
#
#             [164] BESS SoC Reward:  1000.00
#
#
#           [164] Calculated Reward ->  1000.000
#
#
#             [165] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [165] Environment State ->
#                   hour_sin:  0.8367
#                   hour_cos: -0.5477
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1375.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1375.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [165] Selected BESS Action -> charge-1000
#
#
#             [165] Current BESS Charge Cost:  0.00
#
#
#             [165] Future BESS Discharge Savings:  0.00
#
#
#             [165] BESS SoC Reward: -1000.00
#
#
#           [165] Calculated Reward -> -1000.000
#
#
#             [166] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [166] Environment State ->
#                   hour_sin: -0.0089
#                   hour_cos: -1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1130.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1130.30 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [166] Selected BESS Action -> do-nothing
#
#
#             [166] BESS SoC Reward:  1000.00
#
#
#           [166] Calculated Reward ->  1000.000
#
#
#             [167] Solar Surplus Energy Calculation ->
#                     Control Setpoint Ratio:  1.00
#                     Solar Production Energy:  0.00
#                     Solar Full Production Energy:  0.00
#                     Solar Surplus Production Energy:  0.00
#
#
#           [167] Environment State ->
#                   hour_sin: -0.8462
#                   hour_cos: -0.5328
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1120.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1120.80 (kWh)
#                   bess_capacity:  3000.00 (kWh)
#                   bess_cycle_efficiency:  0.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   bess_soc:  100.00
#                   done: False
#
#
#           [167] Selected BESS Action -> charge-1000
#
#
#             [167] Current BESS Charge Cost:  0.00
#
#
#             [167] Future BESS Discharge Savings:  0.00
#
#
#             [167] BESS SoC Reward: -1000.00
#
#
#           [167] Calculated Reward -> -1000.000
#
# Episode terminal state reached !
#
# Total Episode Reward:  54.32
#
# Save agent's learned policy.

# %%
# agent.display_action_value_table()

# %% [markdown]
# ### Display Trained Agent's Performance

# %%
experience_df = pd.read_csv("agent_learned_policy.csv", header=0)

# %%
experience_df.head()

performance_df = experience_df[['day_week',
                                'day_saturday', 
                                'day_sunday', 
                                'tou_peak', 
                                'tou_standard', 
                                'tou_offpeak', 
                                'grid_import_energy', 
                                'solar_prod_energy', 
                                'solar_ctlr_setpoint', 
                                'bess_avail_discharge_energy', 
                                'bess_soc', 
                                'action_name', 
                                'reward_earned']]

performance_df.loc[ : ,'cumulative_reward'] = performance_df['reward_earned'].cumsum()

performance_df.index = load_profile_filtered_df.index
# Out:
# /tmp/ipykernel_44001/1413746927.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   performance_df.loc[ : ,'cumulative_reward'] = performance_df['reward_earned'].cumsum()

# %%
# performance_df.head(168)

# %%
filtered_df = performance_df.loc["2024-11-04": "2024-11-10"]

x = filtered_df.index
y1 = filtered_df['bess_soc'].values
y2 = filtered_df['grid_import_energy'].values
y3 = filtered_df['solar_prod_energy'].values
y4 = filtered_df['reward_earned'].values
y5 = filtered_df['cumulative_reward'].values

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(20, 9), sharex=True)

ax1.plot(x, y2, color='orange', label='Grid Import Energy')
ax1.plot(x, y3, color='green', label='Solar Production Energy')
ax1.set_title('Grid Import & Solar Production Energy')
ax1.set_xlabel('Date')
ax1.set_ylabel('Energy (kWh)')
ax1.legend(loc='upper right')

ax2.set_title('RL Agent Control - BESS State of Charge (kWh)')
ax2.set_xlabel('Date')
ax2.set_ylabel('SoC (%)')
ax2.plot(x, y1, color='blue', label='BESS SoC')
ax2.legend(loc='upper right')

ax3.set_title('RL Agent Control - Instantaneous Rewards')
ax3.set_xlabel('Date')
ax3.set_ylabel('Reward')
ax3.plot(x, y4, color='red', label='Inst-Reward')
ax3.legend(loc='upper right')

ax4.set_title('RL Agent Control - Cumulative Reward')
ax4.set_xlabel('Date')
ax4.set_ylabel('Reward')
ax4.plot(x, y5, color='purple', label='Cumsum-Reward')
ax4.legend(loc='upper right')

fig.tight_layout()  # Adjust layout to prevent overlap
plt.show()
