# %% [markdown]
# ### Import All Library Dependencies

# %%
import os
import sys
import traceback
import logging as log
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from microgrid_env import MicrogridEnv

log.basicConfig(format="Line:%(lineno)d-%(funcName)s-%(levelname)s:  %(message)s")
log.getLogger().setLevel(log.INFO)

# %% [markdown]
# ### Data Pre-processing

# %%
df = pd.read_csv("load_profile_data_nov2024.csv", header=0)

# %%
df.head()
# Out:
#      entry_time weekday tou_time_slot  grid_import_energy  solar_prod_energy  \
# 0  11/1/24 0:00  Friday             o              1339.4                0.0
# 1  11/1/24 1:00  Friday             o              1388.9                0.0
# 2  11/1/24 2:00  Friday             o              1444.8                0.0
# 3  11/1/24 3:00  Friday             o              1463.7                0.0
# 4  11/1/24 4:00  Friday             o              1467.0                0.0
#
#    solar_ctlr_setpoint  site_load_energy
# 0                100.0            1339.4
# 1                100.0            1388.9
# 2                100.0            1444.8
# 3                100.0            1463.7
# 4                100.0            1467.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   entry_time           720 non-null    object
#  1   weekday              720 non-null    object
#  2   tou_time_slot        720 non-null    object
#  3   grid_import_energy   720 non-null    float64
#  4   solar_prod_energy    720 non-null    float64
#  5   solar_ctlr_setpoint  720 non-null    float64
#  6   site_load_energy     720 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 39.5+ KB

# %%
df['timestamp'] = pd.to_datetime(df['entry_time'], format="mixed")

# %%
df['ts_hour'] = df['timestamp'].dt.hour

# %%
def convert_weekday(wkd: str) -> str:
    if wkd in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']:
        return 'week'
    else:
        return wkd.lower()

# %%
# One-hot encode the Weekday field
df['weekday_fmt'] = df['weekday'].map(lambda wkd: convert_weekday(wkd))
df['day_week'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'week' else 0)
df['day_saturday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'saturday' else 0)
df['day_sunday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'sunday' else 0)

# %%
# One-hot encode the TOU Timeslot field
df['tou_offpeak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'o' else 0)
df['tou_standard'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 's' else 0)
df['tou_peak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'p' else 0)

# %%
# Convert hour field to unit circle coordinates
df['ts_hour_sin'] = np.sin( df['ts_hour'] )
df['ts_hour_cos'] = np.cos( df['ts_hour'] )

# %%
df.set_index('timestamp', inplace=True)

# %%
df.drop(['entry_time', 'ts_hour', 'weekday', 'weekday_fmt', 'tou_time_slot'], axis=1, inplace=True)

# %%
load_profile_df = df[['ts_hour_sin', 'ts_hour_cos', 'tou_offpeak', 'tou_standard', 'tou_peak', 'day_week', 'day_saturday', 'day_sunday', 'site_load_energy', 'solar_prod_energy', 'solar_ctlr_setpoint', 'grid_import_energy']]

# %%
load_profile_df.head(48)
# Out:
#                      ts_hour_sin  ts_hour_cos  tou_offpeak  tou_standard  \
# timestamp
# 2024-11-01 00:00:00     0.000000     1.000000            1             0
# timestamp
# 2024-11-04 00:00:00            1031.9                0.0                100.0
# 2024-11-04 01:00:00            1191.1                0.0                100.0
# 2024-11-04 02:00:00            1233.8                0.0                100.0
# 2024-11-04 03:00:00            1145.3                0.0                100.0
# 2024-11-04 04:00:00            1247.1                0.0                100.0
#
#                      grid_import_energy
# timestamp
# 2024-11-04 00:00:00              1031.9
# 2024-11-04 01:00:00              1191.1
# 2024-11-04 02:00:00              1233.8
# 2024-11-04 03:00:00              1145.3
# 2024-11-04 04:00:00              1247.1

# %%
load_profile_filtered_df.describe().T
# Out:
#                      count         mean         std         min          25%  \
# ts_hour_sin          168.0     0.040825    0.699499   -0.999990    -0.595763
# ts_hour_cos          168.0    -0.022538    0.717287   -0.999961    -0.680155
# tou_offpeak          168.0     0.446429    0.498608    0.000000     0.000000
# tou_standard         168.0     0.404762    0.492313    0.000000     0.000000
# tou_peak             168.0     0.148810    0.356965    0.000000     0.000000
# day_week             168.0     0.714286    0.453104    0.000000     0.000000
# day_saturday         168.0     0.142857    0.350973    0.000000     0.000000
# day_sunday           168.0     0.142857    0.350973    0.000000     0.000000
# site_load_energy     168.0  1154.939940  304.294259  534.680000  1036.775000
# solar_prod_energy    168.0   224.364345  337.372179    0.000000     0.000000
# solar_ctlr_setpoint  168.0    98.791970    4.022742   75.729000   100.000000
# grid_import_energy   168.0   930.575595  380.815458   74.500000   604.375000
#
#                              50%          75%          max
# ts_hour_sin             0.070560     0.701904     0.990607
# ts_hour_cos            -0.070537     0.683713     1.000000
# tou_offpeak             0.000000     1.000000     1.000000
# tou_standard            0.000000     1.000000     1.000000
# tou_peak                0.000000     0.000000     1.000000
# day_week                1.000000     1.000000     1.000000
# day_saturday            0.000000     0.000000     1.000000
# day_sunday              0.000000     0.000000     1.000000
# site_load_energy     1217.150000  1377.600000  1652.700000
# solar_prod_energy      18.125000   324.887500  1266.300000
# solar_ctlr_setpoint   100.000000   100.000000   100.000000
# grid_import_energy   1000.800000  1221.650000  1644.600000

# %% [markdown]
# ### Create Microgrid Environment

# %%
env = MicrogridEnv(data=load_profile_filtered_df)
# Out:
# Environment Defaults:
#
#       Grid Notified Maximum Demand: 2000.0 kVA
#       BESS Capacity: 3000.0 kWh
#       BESS Actions: charge-1500, charge-1000, charge-500, do-nothing, discharge-500, discharge-1000, discharge-1500
#       Reward Discount Factor: 0.99
#
#
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2024-11-04 00:00:00 to 2024-11-10 23:00:00
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ts_hour_sin          168 non-null    float64
#  1   ts_hour_cos          168 non-null    float64
#  2   tou_offpeak          168 non-null    int64
#  3   tou_standard         168 non-null    int64
#  4   tou_peak             168 non-null    int64
#  5   day_week             168 non-null    int64
#  6   day_saturday         168 non-null    int64
#  7   day_sunday           168 non-null    int64
#  8   site_load_energy     168 non-null    float64
#  9   solar_prod_energy    168 non-null    float64
#  10  solar_ctlr_setpoint  168 non-null    float64
#  11  grid_import_energy   168 non-null    float64
# dtypes: float64(6), int64(6)
# memory usage: 17.1 KB
# None

# %% [markdown]
# ### Run Environment

# %%
epsilon = 0.2
reward_buffer = []
total_episode_reward = 0.0

state, reward, done = env.reset()

while(not done):

    reward_buffer.append(total_episode_reward)

    if np.random.random() <= epsilon:

        action = np.random.choice(7)
        
    else:
        
        action = env.rule_based_policy(state=state)

    state, reward, done = env.step(action=action)

    total_episode_reward = (0.99 * total_episode_reward) + reward
# Out:
#       [0] Environment State ->
#               hour_sin:  0.0000
#               hour_cos:  1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1031.90 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1031.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [0] Selected Action -> charge-500
#
#
#       [0] Reward -> -0.000
#
#
#       [1] Environment State ->
#               hour_sin:  0.8415
#               hour_cos:  0.5403
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1191.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1191.10 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [1] Selected Action -> do-nothing
#
#
#       [1] Reward ->  0.000
#
#
#       [2] Environment State ->
#               hour_sin:  0.9093
#               hour_cos: -0.4161
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1233.80 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1233.80 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [2] Selected Action -> do-nothing
#
#
#       [2] Reward ->  0.000
#
#
#       [3] Environment State ->
#               hour_sin:  0.1411
#               hour_cos: -0.9900
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1145.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1145.30 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [3] Selected Action -> do-nothing
#
#
#       [3] Reward ->  0.000
#
#
#       [4] Environment State ->
#               hour_sin: -0.7568
#               hour_cos: -0.6536
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1247.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1247.10 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [4] Selected Action -> do-nothing
#
#
#       [4] Reward ->  0.000
#
#
#       [5] Environment State ->
#               hour_sin: -0.9589
#               hour_cos:  0.2837
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1356.72 (kWh)
#               solar_prod_energy:  30.52 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  2.25 (%)
#               grid_import_energy:  1326.20 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [5] Selected Action -> do-nothing
#
#
#       [5] Reward ->  0.000
#
#
#       [6] Environment State ->
#               hour_sin: -0.2794
#               hour_cos:  0.9602
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1340.90 (kWh)
#               solar_prod_energy:  186.90 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  13.94 (%)
#               grid_import_energy:  1154.00 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [6] Selected Action -> discharge-1500
#
#
#       [6] Reward ->  5.770
#
#
#       [7] Environment State ->
#               hour_sin:  0.6570
#               hour_cos:  0.7539
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1218.30 (kWh)
#               solar_prod_energy:  545.90 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  44.81 (%)
#               grid_import_energy:  672.40 (kWh)
#               bess_avail_discharge_energy:  1846.00 (kWh)
#               done: False
#
#
#       [7] Selected Action -> discharge-1500
#
#
#       [7] Reward ->  3.362
#
#
#       [8] Environment State ->
#               hour_sin:  0.9894
#               hour_cos: -0.1455
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1263.20 (kWh)
#               solar_prod_energy:  832.30 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  65.89 (%)
#               grid_import_energy:  430.90 (kWh)
#               bess_avail_discharge_energy:  1173.60 (kWh)
#               done: False
#
#
#       [8] Selected Action -> discharge-1500
#
#
#       [8] Reward ->  2.155
#
#
#       [9] Environment State ->
#               hour_sin:  0.4121
#               hour_cos: -0.9111
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1359.30 (kWh)
#               solar_prod_energy:  1123.60 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  82.66 (%)
#               grid_import_energy:  235.70 (kWh)
#               bess_avail_discharge_energy:  742.70 (kWh)
#               done: False
#
#
#       [9] Selected Action -> charge-500
#
#
#       [9] Reward -> -0.700
#
#
#       [10] Environment State ->
#               hour_sin: -0.5440
#               hour_cos: -0.8391
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1272.70 (kWh)
#               solar_prod_energy:  1198.20 (kWh)
#               solar_ctlr_setpoint:  94.30 (%)
#               solar_vs_load_ratio:  94.15 (%)
#               grid_import_energy:  74.50 (kWh)
#               bess_avail_discharge_energy:  1242.70 (kWh)
#               done: False
#
#
#       [10] Selected Action -> charge-500
#
#
#       [10] Reward -> -0.743
#
#
#       [11] Environment State ->
#               hour_sin: -1.0000
#               hour_cos:  0.0044
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1194.60 (kWh)
#               solar_prod_energy:  1114.00 (kWh)
#               solar_ctlr_setpoint:  79.34 (%)
#               solar_vs_load_ratio:  93.25 (%)
#               grid_import_energy:  80.60 (kWh)
#               bess_avail_discharge_energy:  1742.70 (kWh)
#               done: False
#
#
#       [11] Selected Action -> discharge-500
#
#
#       [11] Reward ->  0.161
#
#
#       [12] Environment State ->
#               hour_sin: -0.5366
#               hour_cos:  0.8439
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1296.00 (kWh)
#               solar_prod_energy:  1212.70 (kWh)
#               solar_ctlr_setpoint:  75.73 (%)
#               solar_vs_load_ratio:  93.57 (%)
#               grid_import_energy:  83.30 (kWh)
#               bess_avail_discharge_energy:  1662.10 (kWh)
#               done: False
#
#
#       [12] Selected Action -> charge-500
#
#
#       [12] Reward -> -0.933
#
#
#       [13] Environment State ->
#               hour_sin:  0.4202
#               hour_cos:  0.9074
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1223.80 (kWh)
#               solar_prod_energy:  984.30 (kWh)
#               solar_ctlr_setpoint:  81.28 (%)
#               solar_vs_load_ratio:  80.43 (%)
#               grid_import_energy:  239.50 (kWh)
#               bess_avail_discharge_energy:  2162.10 (kWh)
#               done: False
#
#
#       [13] Selected Action -> do-nothing
#
#
#       [13] Reward ->  0.000
#
#
#       [14] Environment State ->
#               hour_sin:  0.9906
#               hour_cos:  0.1367
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1216.00 (kWh)
#               solar_prod_energy:  885.20 (kWh)
#               solar_ctlr_setpoint:  83.61 (%)
#               solar_vs_load_ratio:  72.80 (%)
#               grid_import_energy:  330.80 (kWh)
#               bess_avail_discharge_energy:  2162.10 (kWh)
#               done: False
#
#
#       [14] Selected Action -> charge-500
#
#
#       [14] Reward -> -0.804
#
#
#       [15] Environment State ->
#               hour_sin:  0.6503
#               hour_cos: -0.7597
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1133.50 (kWh)
#               solar_prod_energy:  689.90 (kWh)
#               solar_ctlr_setpoint:  93.03 (%)
#               solar_vs_load_ratio:  60.86 (%)
#               grid_import_energy:  443.60 (kWh)
#               bess_avail_discharge_energy:  2662.10 (kWh)
#               done: False
#
#
#       [15] Selected Action -> do-nothing
#
#
#       [15] Reward ->  0.000
#
#
#       [16] Environment State ->
#               hour_sin: -0.2879
#               hour_cos: -0.9577
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1051.50 (kWh)
#               solar_prod_energy:  286.90 (kWh)
#               solar_ctlr_setpoint:  97.94 (%)
#               solar_vs_load_ratio:  27.28 (%)
#               grid_import_energy:  764.60 (kWh)
#               bess_avail_discharge_energy:  2662.10 (kWh)
#               done: False
#
#
#       [16] Selected Action -> do-nothing
#
#
#       [16] Reward ->  0.000
#
#
#       [17] Environment State ->
#               hour_sin: -0.9614
#               hour_cos: -0.2752
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1337.10 (kWh)
#               solar_prod_energy:  109.30 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  8.17 (%)
#               grid_import_energy:  1227.80 (kWh)
#               bess_avail_discharge_energy:  2662.10 (kWh)
#               done: False
#
#
#       [17] Selected Action -> discharge-1500
#
#
#       [17] Reward ->  6.139
#
#
#       [18] Environment State ->
#               hour_sin: -0.7510
#               hour_cos:  0.6603
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1117.86 (kWh)
#               solar_prod_energy:  30.26 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  2.71 (%)
#               grid_import_energy:  1087.60 (kWh)
#               bess_avail_discharge_energy:  1434.30 (kWh)
#               done: False
#
#
#       [18] Selected Action -> discharge-1500
#
#
#       [18] Reward ->  5.438
#
#
#       [19] Environment State ->
#               hour_sin:  0.1499
#               hour_cos:  0.9887
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1082.90 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1082.90 (kWh)
#               bess_avail_discharge_energy:  346.70 (kWh)
#               done: False
#
#
#       [19] Selected Action -> do-nothing
#
#
#       [19] Reward ->  0.000
#
#
#       [20] Environment State ->
#               hour_sin:  0.9129
#               hour_cos:  0.4081
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1139.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1139.30 (kWh)
#               bess_avail_discharge_energy:  346.70 (kWh)
#               done: False
#
#
#       [20] Selected Action -> do-nothing
#
#
#       [20] Reward ->  0.000
#
#
#       [21] Environment State ->
#               hour_sin:  0.8367
#               hour_cos: -0.5477
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1074.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1074.10 (kWh)
#               bess_avail_discharge_energy:  346.70 (kWh)
#               done: False
#
#
#       [21] Selected Action -> discharge-1000
#
#
#       [21] Reward ->  0.693
#
#
#       [22] Environment State ->
#               hour_sin: -0.0089
#               hour_cos: -1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1126.20 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1126.20 (kWh)
#               bess_avail_discharge_energy:  0.00 (kWh)
#               done: False
#
#
#       [22] Selected Action -> charge-1500
#
#
#       [22] Reward -> -1.223
#
#
#       [23] Environment State ->
#               hour_sin: -0.8462
#               hour_cos: -0.5328
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1438.50 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1438.50 (kWh)
#               bess_avail_discharge_energy:  873.80 (kWh)
#               done: False
#
#
#       [23] Selected Action -> charge-1500
#
#
#       [23] Reward -> -0.786
#
#
#       [24] Environment State ->
#               hour_sin:  0.0000
#               hour_cos:  1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1255.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1255.30 (kWh)
#               bess_avail_discharge_energy:  1435.30 (kWh)
#               done: False
#
#
#       [24] Selected Action -> charge-1500
#
#
#       [24] Reward -> -1.043
#
#
#       [25] Environment State ->
#               hour_sin:  0.8415
#               hour_cos:  0.5403
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1339.70 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1339.70 (kWh)
#               bess_avail_discharge_energy:  2180.00 (kWh)
#               done: False
#
#
#       [25] Selected Action -> discharge-1000
#
#
#       [25] Reward ->  1.000
#
#
#       [26] Environment State ->
#               hour_sin:  0.9093
#               hour_cos: -0.4161
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1292.20 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1292.20 (kWh)
#               bess_avail_discharge_energy:  1180.00 (kWh)
#               done: False
#
#
#       [26] Selected Action -> charge-1000
#
#
#       [26] Reward -> -0.991
#
#
#       [27] Environment State ->
#               hour_sin:  0.1411
#               hour_cos: -0.9900
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1201.40 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1201.40 (kWh)
#               bess_avail_discharge_energy:  1887.80 (kWh)
#               done: False
#
#
#       [27] Selected Action -> charge-1500
#
#
#       [27] Reward -> -1.118
#
#
#       [28] Environment State ->
#               hour_sin: -0.7568
#               hour_cos: -0.6536
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1159.90 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1159.90 (kWh)
#               bess_avail_discharge_energy:  2686.40 (kWh)
#               done: False
#
#
#       [28] Selected Action -> charge-1500
#
#
#       [28] Reward -> -0.314
#
#
#       [29] Environment State ->
#               hour_sin: -0.9589
#               hour_cos:  0.2837
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1147.87 (kWh)
#               solar_prod_energy:  10.97 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.96 (%)
#               grid_import_energy:  1136.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [29] Selected Action -> do-nothing
#
#
#       [29] Reward ->  0.000
#
#
#       [30] Environment State ->
#               hour_sin: -0.2794
#               hour_cos:  0.9602
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1269.61 (kWh)
#               solar_prod_energy:  102.91 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  8.11 (%)
#               grid_import_energy:  1166.70 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [30] Selected Action -> discharge-1000
#
#
#       [30] Reward ->  5.000
#
#
#       [31] Environment State ->
#               hour_sin:  0.6570
#               hour_cos:  0.7539
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1284.45 (kWh)
#               solar_prod_energy:  212.85 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  16.57 (%)
#               grid_import_energy:  1071.60 (kWh)
#               bess_avail_discharge_energy:  2000.00 (kWh)
#               done: False
#
#
#       [31] Selected Action -> charge-500
#
#
#       [31] Reward -> -0.700
#
#
#       [32] Environment State ->
#               hour_sin:  0.9894
#               hour_cos: -0.1455
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1302.30 (kWh)
#               solar_prod_energy:  310.70 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  23.86 (%)
#               grid_import_energy:  991.60 (kWh)
#               bess_avail_discharge_energy:  2500.00 (kWh)
#               done: False
#
#
#       [32] Selected Action -> discharge-1500
#
#
#       [32] Reward ->  4.958
#
#
#       [33] Environment State ->
#               hour_sin:  0.4121
#               hour_cos: -0.9111
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1350.16 (kWh)
#               solar_prod_energy:  496.26 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  36.76 (%)
#               grid_import_energy:  853.90 (kWh)
#               bess_avail_discharge_energy:  1508.40 (kWh)
#               done: False
#
#
#       [33] Selected Action -> do-nothing
#
#
#       [33] Reward ->  0.000
#
#
#       [34] Environment State ->
#               hour_sin: -0.5440
#               hour_cos: -0.8391
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1295.30 (kWh)
#               solar_prod_energy:  969.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  74.81 (%)
#               grid_import_energy:  326.30 (kWh)
#               bess_avail_discharge_energy:  1508.40 (kWh)
#               done: False
#
#
#       [34] Selected Action -> charge-500
#
#
#       [34] Reward -> -0.700
#
#
#       [35] Environment State ->
#               hour_sin: -1.0000
#               hour_cos:  0.0044
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1393.60 (kWh)
#               solar_prod_energy:  884.50 (kWh)
#               solar_ctlr_setpoint:  87.70 (%)
#               solar_vs_load_ratio:  63.47 (%)
#               grid_import_energy:  509.10 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [35] Selected Action -> do-nothing
#
#
#       [35] Reward ->  0.000
#
#
#       [36] Environment State ->
#               hour_sin: -0.5366
#               hour_cos:  0.8439
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1341.70 (kWh)
#               solar_prod_energy:  404.00 (kWh)
#               solar_ctlr_setpoint:  98.86 (%)
#               solar_vs_load_ratio:  30.11 (%)
#               grid_import_energy:  937.70 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [36] Selected Action -> do-nothing
#
#
#       [36] Reward ->  0.000
#
#
#       [37] Environment State ->
#               hour_sin:  0.4202
#               hour_cos:  0.9074
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1191.60 (kWh)
#               solar_prod_energy:  256.00 (kWh)
#               solar_ctlr_setpoint:  96.31 (%)
#               solar_vs_load_ratio:  21.48 (%)
#               grid_import_energy:  935.60 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [37] Selected Action -> do-nothing
#
#
#       [37] Reward ->  0.000
#
#
#       [38] Environment State ->
#               hour_sin:  0.9906
#               hour_cos:  0.1367
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1292.70 (kWh)
#               solar_prod_energy:  667.00 (kWh)
#               solar_ctlr_setpoint:  97.23 (%)
#               solar_vs_load_ratio:  51.60 (%)
#               grid_import_energy:  625.70 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [38] Selected Action -> do-nothing
#
#
#       [38] Reward ->  0.000
#
#
#       [39] Environment State ->
#               hour_sin:  0.6503
#               hour_cos: -0.7597
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1272.60 (kWh)
#               solar_prod_energy:  664.20 (kWh)
#               solar_ctlr_setpoint:  99.67 (%)
#               solar_vs_load_ratio:  52.19 (%)
#               grid_import_energy:  608.40 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [39] Selected Action -> do-nothing
#
#
#       [39] Reward ->  0.000
#
#
#       [40] Environment State ->
#               hour_sin: -0.2879
#               hour_cos: -0.9577
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1191.50 (kWh)
#               solar_prod_energy:  422.70 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  35.48 (%)
#               grid_import_energy:  768.80 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [40] Selected Action -> do-nothing
#
#
#       [40] Reward ->  0.000
#
#
#       [41] Environment State ->
#               hour_sin: -0.9614
#               hour_cos: -0.2752
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1056.40 (kWh)
#               solar_prod_energy:  123.60 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  11.70 (%)
#               grid_import_energy:  932.80 (kWh)
#               bess_avail_discharge_energy:  2008.40 (kWh)
#               done: False
#
#
#       [41] Selected Action -> discharge-1500
#
#
#       [41] Reward ->  4.664
#
#
#       [42] Environment State ->
#               hour_sin: -0.7510
#               hour_cos:  0.6603
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  986.65 (kWh)
#               solar_prod_energy:  11.85 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  1.20 (%)
#               grid_import_energy:  974.80 (kWh)
#               bess_avail_discharge_energy:  1075.60 (kWh)
#               done: False
#
#
#       [42] Selected Action -> discharge-1500
#
#
#       [42] Reward ->  4.874
#
#
#       [43] Environment State ->
#               hour_sin:  0.1499
#               hour_cos:  0.9887
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  971.70 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  971.70 (kWh)
#               bess_avail_discharge_energy:  100.80 (kWh)
#               done: False
#
#
#       [43] Selected Action -> do-nothing
#
#
#       [43] Reward ->  0.000
#
#
#       [44] Environment State ->
#               hour_sin:  0.9129
#               hour_cos:  0.4081
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1000.60 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1000.60 (kWh)
#               bess_avail_discharge_energy:  100.80 (kWh)
#               done: False
#
#
#       [44] Selected Action -> do-nothing
#
#
#       [44] Reward ->  0.000
#
#
#       [45] Environment State ->
#               hour_sin:  0.8367
#               hour_cos: -0.5477
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1001.00 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1001.00 (kWh)
#               bess_avail_discharge_energy:  100.80 (kWh)
#               done: False
#
#
#       [45] Selected Action -> do-nothing
#
#
#       [45] Reward ->  0.000
#
#
#       [46] Environment State ->
#               hour_sin: -0.0089
#               hour_cos: -1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1146.60 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1146.60 (kWh)
#               bess_avail_discharge_energy:  100.80 (kWh)
#               done: False
#
#
#       [46] Selected Action -> do-nothing
#
#
#       [46] Reward ->  0.000
#
#
#       [47] Environment State ->
#               hour_sin: -0.8462
#               hour_cos: -0.5328
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1461.20 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1461.20 (kWh)
#               bess_avail_discharge_energy:  100.80 (kWh)
#               done: False
#
#
#       [47] Selected Action -> discharge-500
#
#
#       [47] Reward ->  0.101
#
#
#       [48] Environment State ->
#               hour_sin:  0.0000
#               hour_cos:  1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1343.20 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1343.20 (kWh)
#               bess_avail_discharge_energy:  0.00 (kWh)
#               done: False
#
#
#       [48] Selected Action -> charge-1500
#
#
#       [48] Reward -> -0.920
#
#
#       [49] Environment State ->
#               hour_sin:  0.8415
#               hour_cos:  0.5403
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1408.00 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1408.00 (kWh)
#               bess_avail_discharge_energy:  656.80 (kWh)
#               done: False
#
#
#       [49] Selected Action -> charge-1500
#
#
#       [49] Reward -> -0.829
#
#
#       [50] Environment State ->
#               hour_sin:  0.9093
#               hour_cos: -0.4161
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1369.90 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1369.90 (kWh)
#               bess_avail_discharge_energy:  1248.80 (kWh)
#               done: False
#
#
#       [50] Selected Action -> charge-1500
#
#
#       [50] Reward -> -0.882
#
#
#       [51] Environment State ->
#               hour_sin:  0.1411
#               hour_cos: -0.9900
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1188.50 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1188.50 (kWh)
#               bess_avail_discharge_energy:  1878.90 (kWh)
#               done: False
#
#
#       [51] Selected Action -> charge-1500
#
#
#       [51] Reward -> -1.136
#
#
#       [52] Environment State ->
#               hour_sin: -0.7568
#               hour_cos: -0.6536
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1210.40 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1210.40 (kWh)
#               bess_avail_discharge_energy:  2690.40 (kWh)
#               done: False
#
#
#       [52] Selected Action -> charge-1500
#
#
#       [52] Reward -> -0.310
#
#
#       [53] Environment State ->
#               hour_sin: -0.9589
#               hour_cos:  0.2837
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1249.42 (kWh)
#               solar_prod_energy:  37.52 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  3.00 (%)
#               grid_import_energy:  1211.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [53] Selected Action -> charge-1000
#
#
#       [53] Reward -> -0.000
#
#
#       [54] Environment State ->
#               hour_sin: -0.2794
#               hour_cos:  0.9602
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1326.60 (kWh)
#               solar_prod_energy:  224.40 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  16.92 (%)
#               grid_import_energy:  1102.20 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [54] Selected Action -> discharge-1500
#
#
#       [54] Reward ->  5.511
#
#
#       [55] Environment State ->
#               hour_sin:  0.6570
#               hour_cos:  0.7539
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1384.50 (kWh)
#               solar_prod_energy:  479.80 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  34.66 (%)
#               grid_import_energy:  904.70 (kWh)
#               bess_avail_discharge_energy:  1897.80 (kWh)
#               done: False
#
#
#       [55] Selected Action -> discharge-1500
#
#
#       [55] Reward ->  4.524
#
#
#       [56] Environment State ->
#               hour_sin:  0.9894
#               hour_cos: -0.1455
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1396.90 (kWh)
#               solar_prod_energy:  845.20 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  60.51 (%)
#               grid_import_energy:  551.70 (kWh)
#               bess_avail_discharge_energy:  993.10 (kWh)
#               done: False
#
#
#       [56] Selected Action -> discharge-1500
#
#
#       [56] Reward ->  2.759
#
#
#       [57] Environment State ->
#               hour_sin:  0.4121
#               hour_cos: -0.9111
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1329.50 (kWh)
#               solar_prod_energy:  1095.60 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  82.41 (%)
#               grid_import_energy:  233.90 (kWh)
#               bess_avail_discharge_energy:  441.40 (kWh)
#               done: False
#
#
#       [57] Selected Action -> charge-500
#
#
#       [57] Reward -> -0.700
#
#
#       [58] Environment State ->
#               hour_sin: -0.5440
#               hour_cos: -0.8391
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1426.00 (kWh)
#               solar_prod_energy:  1266.30 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  88.80 (%)
#               grid_import_energy:  159.70 (kWh)
#               bess_avail_discharge_energy:  941.40 (kWh)
#               done: False
#
#
#       [58] Selected Action -> charge-500
#
#
#       [58] Reward -> -0.700
#
#
#       [59] Environment State ->
#               hour_sin: -1.0000
#               hour_cos:  0.0044
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1546.10 (kWh)
#               solar_prod_energy:  1063.60 (kWh)
#               solar_ctlr_setpoint:  97.83 (%)
#               solar_vs_load_ratio:  68.79 (%)
#               grid_import_energy:  482.50 (kWh)
#               bess_avail_discharge_energy:  1441.40 (kWh)
#               done: False
#
#
#       [59] Selected Action -> do-nothing
#
#
#       [59] Reward ->  0.000
#
#
#       [60] Environment State ->
#               hour_sin: -0.5366
#               hour_cos:  0.8439
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1491.50 (kWh)
#               solar_prod_energy:  1095.30 (kWh)
#               solar_ctlr_setpoint:  99.41 (%)
#               solar_vs_load_ratio:  73.44 (%)
#               grid_import_energy:  396.20 (kWh)
#               bess_avail_discharge_energy:  1441.40 (kWh)
#               done: False
#
#
#       [60] Selected Action -> charge-500
#
#
#       [60] Reward -> -0.704
#
#
#       [61] Environment State ->
#               hour_sin:  0.4202
#               hour_cos:  0.9074
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1489.50 (kWh)
#               solar_prod_energy:  1125.70 (kWh)
#               solar_ctlr_setpoint:  95.31 (%)
#               solar_vs_load_ratio:  75.58 (%)
#               grid_import_energy:  363.80 (kWh)
#               bess_avail_discharge_energy:  1941.40 (kWh)
#               done: False
#
#
#       [61] Selected Action -> charge-500
#
#
#       [61] Reward -> -0.733
#
#
#       [62] Environment State ->
#               hour_sin:  0.9906
#               hour_cos:  0.1367
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1436.90 (kWh)
#               solar_prod_energy:  1057.20 (kWh)
#               solar_ctlr_setpoint:  98.91 (%)
#               solar_vs_load_ratio:  73.58 (%)
#               grid_import_energy:  379.70 (kWh)
#               bess_avail_discharge_energy:  2441.40 (kWh)
#               done: False
#
#
#       [62] Selected Action -> charge-500
#
#
#       [62] Reward -> -0.707
#
#
#       [63] Environment State ->
#               hour_sin:  0.6503
#               hour_cos: -0.7597
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1151.40 (kWh)
#               solar_prod_energy:  478.40 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  41.55 (%)
#               grid_import_energy:  673.00 (kWh)
#               bess_avail_discharge_energy:  2941.40 (kWh)
#               done: False
#
#
#       [63] Selected Action -> do-nothing
#
#
#       [63] Reward ->  0.000
#
#
#       [64] Environment State ->
#               hour_sin: -0.2879
#               hour_cos: -0.9577
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1296.10 (kWh)
#               solar_prod_energy:  345.10 (kWh)
#               solar_ctlr_setpoint:  95.76 (%)
#               solar_vs_load_ratio:  26.63 (%)
#               grid_import_energy:  951.00 (kWh)
#               bess_avail_discharge_energy:  2941.40 (kWh)
#               done: False
#
#
#       [64] Selected Action -> discharge-1500
#
#
#       [64] Reward ->  1.902
#
#
#       [65] Environment State ->
#               hour_sin: -0.9614
#               hour_cos: -0.2752
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1144.10 (kWh)
#               solar_prod_energy:  156.90 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  13.71 (%)
#               grid_import_energy:  987.20 (kWh)
#               bess_avail_discharge_energy:  1990.40 (kWh)
#               done: False
#
#
#       [65] Selected Action -> discharge-1500
#
#
#       [65] Reward ->  4.936
#
#
#       [66] Environment State ->
#               hour_sin: -0.7510
#               hour_cos:  0.6603
#               tou_offpeak:  0
#               tou_standard:  0
#               tou_peak:  1
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1064.02 (kWh)
#               solar_prod_energy:  16.52 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  1.55 (%)
#               grid_import_energy:  1047.50 (kWh)
#               bess_avail_discharge_energy:  1003.20 (kWh)
#               done: False
#
#
#       [66] Selected Action -> discharge-1500
#
#
#       [66] Reward ->  5.016
#
#
#       [67] Environment State ->
#               hour_sin:  0.1499
#               hour_cos:  0.9887
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1038.40 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1038.40 (kWh)
#               bess_avail_discharge_energy:  0.00 (kWh)
#               done: False
#
#
#       [67] Selected Action -> discharge-1500
#
#
#       [67] Reward ->  0.000
#
#
#       [68] Environment State ->
#               hour_sin:  0.9129
#               hour_cos:  0.4081
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1261.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1261.30 (kWh)
#               bess_avail_discharge_energy:  0.00 (kWh)
#               done: False
#
#
#       [68] Selected Action -> do-nothing
#
#
#       [68] Reward ->  0.000
#
#
#       [69] Environment State ->
#               hour_sin:  0.8367
#               hour_cos: -0.5477
#               tou_offpeak:  0
#               tou_standard:  1
#               tou_peak:  0
#               day_week:  1
#               day_saturday:  0
#               day_sunday:  0
#               site_load_energy:  1213.70 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1213.70 (kWh)
#               bess_avail_discharge_energy:  0.00 (kWh)
#               done: False
#
#
#       [69] Selected Action -> charge-1000
#
#
#       [69] Reward -> -1.101
#
#
#       [70] Environment State ->
#               hour_sin: -0.0089
# ...
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [144] Selected Action -> do-nothing
#
#
#       [144] Reward ->  0.000
#
#
#       [145] Environment State ->
#               hour_sin:  0.8415
#               hour_cos:  0.5403
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  604.80 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  604.80 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [145] Selected Action -> do-nothing
#
#
#       [145] Reward ->  0.000
#
#
#       [146] Environment State ->
#               hour_sin:  0.9093
#               hour_cos: -0.4161
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  641.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  641.10 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [146] Selected Action -> do-nothing
#
#
#       [146] Reward ->  0.000
#
#
#       [147] Environment State ->
#               hour_sin:  0.1411
#               hour_cos: -0.9900
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  599.90 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  599.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [147] Selected Action -> do-nothing
#
#
#       [147] Reward ->  0.000
#
#
#       [148] Environment State ->
#               hour_sin: -0.7568
#               hour_cos: -0.6536
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  594.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  594.10 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [148] Selected Action -> do-nothing
#
#
#       [148] Reward ->  0.000
#
#
#       [149] Environment State ->
#               hour_sin: -0.9589
#               hour_cos:  0.2837
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  561.82 (kWh)
#               solar_prod_energy:  4.92 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.88 (%)
#               grid_import_energy:  556.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [149] Selected Action -> discharge-1000
#
#
#       [149] Reward ->  0.557
#
#
#       [150] Environment State ->
#               hour_sin: -0.2794
#               hour_cos:  0.9602
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  534.68 (kWh)
#               solar_prod_energy:  42.18 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  7.89 (%)
#               grid_import_energy:  492.50 (kWh)
#               bess_avail_discharge_energy:  2443.10 (kWh)
#               done: False
#
#
#       [150] Selected Action -> charge-1500
#
#
#       [150] Reward -> -0.557
#
#
#       [151] Environment State ->
#               hour_sin:  0.6570
#               hour_cos:  0.7539
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  557.74 (kWh)
#               solar_prod_energy:  141.84 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  25.43 (%)
#               grid_import_energy:  415.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [151] Selected Action -> do-nothing
#
#
#       [151] Reward ->  0.000
#
#
#       [152] Environment State ->
#               hour_sin:  0.9894
#               hour_cos: -0.1455
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  553.92 (kWh)
#               solar_prod_energy:  220.32 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  39.77 (%)
#               grid_import_energy:  333.60 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [152] Selected Action -> do-nothing
#
#
#       [152] Reward ->  0.000
#
#
#       [153] Environment State ->
#               hour_sin:  0.4121
#               hour_cos: -0.9111
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  630.80 (kWh)
#               solar_prod_energy:  302.80 (kWh)
#               solar_ctlr_setpoint:  97.35 (%)
#               solar_vs_load_ratio:  48.00 (%)
#               grid_import_energy:  328.00 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [153] Selected Action -> do-nothing
#
#
#       [153] Reward ->  0.000
#
#
#       [154] Environment State ->
#               hour_sin: -0.5440
#               hour_cos: -0.8391
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  564.38 (kWh)
#               solar_prod_energy:  321.48 (kWh)
#               solar_ctlr_setpoint:  86.77 (%)
#               solar_vs_load_ratio:  56.96 (%)
#               grid_import_energy:  242.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [154] Selected Action -> do-nothing
#
#
#       [154] Reward ->  0.000
#
#
#       [155] Environment State ->
#               hour_sin: -1.0000
#               hour_cos:  0.0044
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  560.51 (kWh)
#               solar_prod_energy:  313.11 (kWh)
#               solar_ctlr_setpoint:  80.21 (%)
#               solar_vs_load_ratio:  55.86 (%)
#               grid_import_energy:  247.40 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [155] Selected Action -> do-nothing
#
#
#       [155] Reward ->  0.000
#
#
#       [156] Environment State ->
#               hour_sin: -0.5366
#               hour_cos:  0.8439
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  540.66 (kWh)
#               solar_prod_energy:  227.76 (kWh)
#               solar_ctlr_setpoint:  82.34 (%)
#               solar_vs_load_ratio:  42.13 (%)
#               grid_import_energy:  312.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [156] Selected Action -> do-nothing
#
#
#       [156] Reward ->  0.000
#
#
#       [157] Environment State ->
#               hour_sin:  0.4202
#               hour_cos:  0.9074
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  583.50 (kWh)
#               solar_prod_energy:  241.90 (kWh)
#               solar_ctlr_setpoint:  91.64 (%)
#               solar_vs_load_ratio:  41.46 (%)
#               grid_import_energy:  341.60 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [157] Selected Action -> do-nothing
#
#
#       [157] Reward ->  0.000
#
#
#       [158] Environment State ->
#               hour_sin:  0.9906
#               hour_cos:  0.1367
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  563.63 (kWh)
#               solar_prod_energy:  19.73 (kWh)
#               solar_ctlr_setpoint:  97.15 (%)
#               solar_vs_load_ratio:  3.50 (%)
#               grid_import_energy:  543.90 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [158] Selected Action -> do-nothing
#
#
#       [158] Reward ->  0.000
#
#
#       [159] Environment State ->
#               hour_sin:  0.6503
#               hour_cos: -0.7597
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  574.48 (kWh)
#               solar_prod_energy:  1.18 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.21 (%)
#               grid_import_energy:  573.30 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [159] Selected Action -> do-nothing
#
#
#       [159] Reward ->  0.000
#
#
#       [160] Environment State ->
#               hour_sin: -0.2879
#               hour_cos: -0.9577
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  548.31 (kWh)
#               solar_prod_energy:  0.01 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  548.30 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [160] Selected Action -> discharge-500
#
#
#       [160] Reward ->  0.500
#
#
#       [161] Environment State ->
#               hour_sin: -0.9614
#               hour_cos: -0.2752
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  612.80 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  612.80 (kWh)
#               bess_avail_discharge_energy:  2500.00 (kWh)
#               done: False
#
#
#       [161] Selected Action -> charge-1500
#
#
#       [161] Reward -> -0.500
#
#
#       [162] Environment State ->
#               hour_sin: -0.7510
#               hour_cos:  0.6603
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  639.60 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  639.60 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [162] Selected Action -> do-nothing
#
#
#       [162] Reward ->  0.000
#
#
#       [163] Environment State ->
#               hour_sin:  0.1499
#               hour_cos:  0.9887
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  749.20 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  749.20 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [163] Selected Action -> charge-500
#
#
#       [163] Reward -> -0.000
#
#
#       [164] Environment State ->
#               hour_sin:  0.9129
#               hour_cos:  0.4081
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  969.10 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  969.10 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [164] Selected Action -> do-nothing
#
#
#       [164] Reward ->  0.000
#
#
#       [165] Environment State ->
#               hour_sin:  0.8367
#               hour_cos: -0.5477
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  1375.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1375.30 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [165] Selected Action -> charge-1500
#
#
#       [165] Reward -> -0.000
#
#
#       [166] Environment State ->
#               hour_sin: -0.0089
#               hour_cos: -1.0000
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  1130.30 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1130.30 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [166] Selected Action -> do-nothing
#
#
#       [166] Reward ->  0.000
#
#
#       [167] Environment State ->
#               hour_sin: -0.8462
#               hour_cos: -0.5328
#               tou_offpeak:  1
#               tou_standard:  0
#               tou_peak:  0
#               day_week:  0
#               day_saturday:  0
#               day_sunday:  1
#               site_load_energy:  1120.80 (kWh)
#               solar_prod_energy:  0.00 (kWh)
#               solar_ctlr_setpoint:  100.00 (%)
#               solar_vs_load_ratio:  0.00 (%)
#               grid_import_energy:  1120.80 (kWh)
#               bess_avail_discharge_energy:  3000.00 (kWh)
#               done: False
#
#
#       [167] Selected Action -> do-nothing
#
#
#       [167] Reward ->  0.000
#
# Episode terminal state reached !

# %% [markdown]
# ### Display Results

# %%
print(f"Final Reward: {total_episode_reward: .2f}k")
# Out:
# Final Reward:  22.90k

# %%
y = np.array(reward_buffer)
x = range( y.shape[0] )
plt.plot(x, y)
