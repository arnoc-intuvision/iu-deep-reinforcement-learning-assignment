# %% [markdown]
# ### Import All Library Dependencies

# %%
import os
import sys
import traceback
import logging as log
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from microgrid_env import MicrogridEnv
from q_learning_agent import QLearningAgent
from torch.utils.tensorboard.writer import SummaryWriter

log.basicConfig(format="Line:%(lineno)d-%(funcName)s-%(levelname)s:  %(message)s")
log.getLogger().setLevel(log.INFO)

# %% [markdown]
# ### Data Pre-processing

# %%
df = pd.read_csv("load_profile_data_nov2024.csv", header=0)

# %%
df.head()
# Out:
#      entry_time weekday tou_time_slot  grid_import_energy  solar_prod_energy  \
# 0  11/1/24 0:00  Friday             o              1339.4                0.0
# 1  11/1/24 1:00  Friday             o              1388.9                0.0
# 2  11/1/24 2:00  Friday             o              1444.8                0.0
# 3  11/1/24 3:00  Friday             o              1463.7                0.0
# 4  11/1/24 4:00  Friday             o              1467.0                0.0
#
#    solar_ctlr_setpoint  site_load_energy
# 0                100.0            1339.4
# 1                100.0            1388.9
# 2                100.0            1444.8
# 3                100.0            1463.7
# 4                100.0            1467.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   entry_time           720 non-null    object
#  1   weekday              720 non-null    object
#  2   tou_time_slot        720 non-null    object
#  3   grid_import_energy   720 non-null    float64
#  4   solar_prod_energy    720 non-null    float64
#  5   solar_ctlr_setpoint  720 non-null    float64
#  6   site_load_energy     720 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 39.5+ KB

# %%
df['timestamp'] = pd.to_datetime(df['entry_time'], format="mixed")

# %%
df['ts_hour'] = df['timestamp'].dt.hour

# %%
def convert_weekday(wkd: str) -> str:
    if wkd in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']:
        return 'week'
    else:
        return wkd.lower()

# %%
# One-hot encode the Weekday field
df['weekday_fmt'] = df['weekday'].map(lambda wkd: convert_weekday(wkd))
df['day_week'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'week' else 0)
df['day_saturday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'saturday' else 0)
df['day_sunday'] = df['weekday_fmt'].map(lambda wkd: 1 if wkd == 'sunday' else 0)

# %%
# One-hot encode the TOU Timeslot field
df['tou_offpeak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'o' else 0)
df['tou_standard'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 's' else 0)
df['tou_peak'] = df['tou_time_slot'].map(lambda tou: 1 if tou == 'p' else 0)

# %%
# Convert hour field to unit circle coordinates
df['ts_hour_sin'] = np.sin( df['ts_hour'] )
df['ts_hour_cos'] = np.cos( df['ts_hour'] )

# %%
df.set_index('timestamp', inplace=True)

# %%
df.drop(['entry_time', 'ts_hour', 'weekday', 'weekday_fmt', 'tou_time_slot'], axis=1, inplace=True)

# %%
load_profile_df = df[['ts_hour_sin', 'ts_hour_cos', 'tou_offpeak', 'tou_standard', 'tou_peak', 'day_week', 'day_saturday', 'day_sunday', 'site_load_energy', 'solar_prod_energy', 'solar_ctlr_setpoint', 'grid_import_energy']]

# %%
load_profile_df.head(48)
# Out:
# 2024-11-04 04:00:00    -0.756802    -0.653644            1             0
#
#                      tou_peak  day_week  day_saturday  day_sunday  \
# timestamp
# 2024-11-04 00:00:00         0         1             0           0
# 2024-11-04 01:00:00         0         1             0           0
# 2024-11-04 02:00:00         0         1             0           0
# 2024-11-04 03:00:00         0         1             0           0
# 2024-11-04 04:00:00         0         1             0           0
#
#                      site_load_energy  solar_prod_energy  solar_ctlr_setpoint  \
# timestamp
# 2024-11-04 00:00:00            1031.9                0.0                100.0
# 2024-11-04 01:00:00            1191.1                0.0                100.0
# 2024-11-04 02:00:00            1233.8                0.0                100.0
# 2024-11-04 03:00:00            1145.3                0.0                100.0
# 2024-11-04 04:00:00            1247.1                0.0                100.0
#
#                      grid_import_energy
# timestamp
# 2024-11-04 00:00:00              1031.9
# 2024-11-04 01:00:00              1191.1
# 2024-11-04 02:00:00              1233.8
# 2024-11-04 03:00:00              1145.3
# 2024-11-04 04:00:00              1247.1

# %%
load_profile_filtered_df.describe().T
# Out:
#                      count         mean         std         min          25%  \
# ts_hour_sin          168.0     0.040825    0.699499   -0.999990    -0.595763
# ts_hour_cos          168.0    -0.022538    0.717287   -0.999961    -0.680155
# tou_offpeak          168.0     0.446429    0.498608    0.000000     0.000000
# tou_standard         168.0     0.404762    0.492313    0.000000     0.000000
# tou_peak             168.0     0.148810    0.356965    0.000000     0.000000
# day_week             168.0     0.714286    0.453104    0.000000     0.000000
# day_saturday         168.0     0.142857    0.350973    0.000000     0.000000
# day_sunday           168.0     0.142857    0.350973    0.000000     0.000000
# site_load_energy     168.0  1154.939940  304.294259  534.680000  1036.775000
# solar_prod_energy    168.0   224.364345  337.372179    0.000000     0.000000
# solar_ctlr_setpoint  168.0    98.791970    4.022742   75.729000   100.000000
# grid_import_energy   168.0   930.575595  380.815458   74.500000   604.375000
#
#                              50%          75%          max
# ts_hour_sin             0.070560     0.701904     0.990607
# ts_hour_cos            -0.070537     0.683713     1.000000
# tou_offpeak             0.000000     1.000000     1.000000
# tou_standard            0.000000     1.000000     1.000000
# tou_peak                0.000000     0.000000     1.000000
# day_week                1.000000     1.000000     1.000000
# day_saturday            0.000000     0.000000     1.000000
# day_sunday              0.000000     0.000000     1.000000
# site_load_energy     1217.150000  1377.600000  1652.700000
# solar_prod_energy      18.125000   324.887500  1266.300000
# solar_ctlr_setpoint   100.000000   100.000000   100.000000
# grid_import_energy   1000.800000  1221.650000  1644.600000

# %% [markdown]
# ### Run Environment

# %% [markdown]
# #### Fix Policy Agent

# %%
# epsilon = 0.2
# reward_buffer = []
# total_episode_reward = 0.0

# env = MicrogridEnv(data=load_profile_filtered_df)

# state, reward, done = env.reset()

# while(not done):

#     reward_buffer.append(total_episode_reward)

#     if np.random.random() <= epsilon:

#         action = np.random.choice(7)
        
#     else:
        
#         action = env.rule_based_policy(state=state)

#     state, reward, done = env.step(action=action)

#     total_episode_reward = (0.99 * total_episode_reward) + reward

# %% [markdown]
# #### Tabular Q-Learning Agent

# %%
agent = QLearningAgent(env=MicrogridEnv(data=load_profile_filtered_df, debug_flag=False))
# writer = SummaryWriter(comment="-q-learning")

TEST_EPISODES = 1

iter_no = 0
best_reward = 0.0

while True:
    
    iter_no += 1

    # Take one step in the environment
    state, action, reward, next_state = agent.sample_env(use_fixed_rule_policy=False)

    # Update q-value function
    agent.value_update(state, action, reward, next_state)

    if (iter_no % 167) > 0:

        continue

    elif iter_no > 500_000:

        print("\n\nCould not solve the environment !!!")
        print("   Best test reward achieved %.3f" % (best_reward))
        break

    else:
        
        test_reward = 0.0 
    
        # Run a test episode to track the performance of the agent
        print(f"[{iter_no}]: Test Agent's Performance: ")
        test_reward += agent.run_test_episode(env=MicrogridEnv(data=load_profile_filtered_df, debug_flag=False))
        print(f"   Average test episode reward: {test_reward: .2f}")
        
        # writer.add_scalar("reward", test_reward, iter_no)
    
        # Keep track of the best average reward achieved in the test episodes
        if test_reward > best_reward:
            print("   Best test reward updated %.3f -> %.3f" % (best_reward, test_reward))
            best_reward = test_reward
    
        # If the average reward achieved in the test episodes are above this threshold, then the agent has converged to a good solution
        # Rule based policy achieves 111.27 average reward per episode
        # RL agent best reward so far: 115.470
        if test_reward > 114.0:
            
            print("Solved in %d iterations!" % iter_no)

            print("\n\nRun final episode with trained agent: ")
            final_reward = agent.run_test_episode(env=MicrogridEnv(data=load_profile_filtered_df, debug_flag=True))
            print(f"Final reward: {final_reward: .2f}")
            
            break

# writer.close()
# Out:
# [167]: Test Agent's Performance:
#    Average test episode reward:  9.08
#    Best test reward updated 0.000 -> 9.082
# [334]: Test Agent's Performance:
#    Average test episode reward:  33.57
#    Best test reward updated 9.082 -> 33.572
# [501]: Test Agent's Performance:
#    Average test episode reward:  40.47
#    Best test reward updated 33.572 -> 40.469
# [668]: Test Agent's Performance:
#    Average test episode reward:  56.57
#    Best test reward updated 40.469 -> 56.566
# [835]: Test Agent's Performance:
#    Average test episode reward:  58.69
#    Best test reward updated 56.566 -> 58.693
# [1002]: Test Agent's Performance:
#    Average test episode reward:  74.82
#    Best test reward updated 58.693 -> 74.821
# [1169]: Test Agent's Performance:
#    Average test episode reward:  81.78
#    Best test reward updated 74.821 -> 81.779
# [1336]: Test Agent's Performance:
#    Average test episode reward:  86.07
#    Best test reward updated 81.779 -> 86.072
# [1503]: Test Agent's Performance:
#    Average test episode reward:  86.07
# [1670]: Test Agent's Performance:
#    Average test episode reward:  84.14
# [1837]: Test Agent's Performance:
#    Average test episode reward:  88.64
#    Best test reward updated 86.072 -> 88.638
# [2004]: Test Agent's Performance:
#    Average test episode reward:  90.89
#    Best test reward updated 88.638 -> 90.888
# [2171]: Test Agent's Performance:
#    Average test episode reward:  90.87
# [2338]: Test Agent's Performance:
#    Average test episode reward:  90.87
# [2505]: Test Agent's Performance:
#    Average test episode reward:  90.87
# [2672]: Test Agent's Performance:
#    Average test episode reward:  94.01
#    Best test reward updated 90.888 -> 94.008
# [2839]: Test Agent's Performance:
#    Average test episode reward:  94.01
# [3006]: Test Agent's Performance:
#    Average test episode reward:  94.01
# [3173]: Test Agent's Performance:
#    Average test episode reward:  94.01
# [3340]: Test Agent's Performance:
#    Average test episode reward:  94.01
# [3507]: Test Agent's Performance:
#    Average test episode reward:  96.14
#    Best test reward updated 94.008 -> 96.144
# [3674]: Test Agent's Performance:
#    Average test episode reward:  96.14
# [3841]: Test Agent's Performance:
#    Average test episode reward:  96.14
# [4008]: Test Agent's Performance:
#    Average test episode reward:  96.14
# [4175]: Test Agent's Performance:
#    Average test episode reward:  96.14
# [4342]: Test Agent's Performance:
#    Average test episode reward:  98.64
#    Best test reward updated 96.144 -> 98.645
# [4509]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [4676]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [4843]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5010]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5177]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5344]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5511]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5678]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [5845]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [6012]: Test Agent's Performance:
#    Average test episode reward:  98.64
# [6179]: Test Agent's Performance:
#    Average test episode reward:  103.97
#    Best test reward updated 98.645 -> 103.971
# [6346]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [6513]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [6680]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [6847]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7014]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7181]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7348]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7515]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7682]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [7849]: Test Agent's Performance:
#    Average test episode reward:  103.97
# [8016]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [8183]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [8350]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [8517]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [8684]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [8851]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9018]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9185]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9352]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9519]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9686]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [9853]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10020]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10187]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10354]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10521]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10688]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [10855]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [11022]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [11189]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [11356]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [11523]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [11690]: Test Agent's Performance:
#    Average test episode reward:  106.69
#    Best test reward updated 103.971 -> 106.688
# [11857]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12024]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12191]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12358]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12525]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12692]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [12859]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13026]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13193]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13360]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13527]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13694]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [13861]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14028]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14195]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14362]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14529]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14696]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [14863]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15030]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15197]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15364]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15531]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15698]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [15865]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16032]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16199]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16366]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16533]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16700]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [16867]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17034]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17201]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17368]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17535]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17702]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [17869]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18036]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18203]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18370]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18537]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18704]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [18871]: Test Agent's Performance:
#    Average test episode reward:  103.71
# [19038]: Test Agent's Performance:
#    Average test episode reward:  103.71
#
: Test Agent's Performance:
#    Average test episode reward:  113.20
# [103540]: Test Agent's Performance:
#    Average test episode reward:  113.20
# [103707]: Test Agent's Performance:
# ...
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  599.90 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  599.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [147] Selected Action -> charge-1000
#
#
#           [147] Reward ->  0.000
#
#
#           [148] Environment State ->
#                   hour_sin: -0.7568
#                   hour_cos: -0.6536
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  594.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  594.10 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [148] Selected Action -> charge-1500
#
#
#           [148] Reward ->  0.000
#
#
#           [149] Environment State ->
#                   hour_sin: -0.9589
#                   hour_cos:  0.2837
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  561.82 (kWh)
#                   solar_prod_energy:  4.92 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.88 (%)
#                   grid_import_energy:  556.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [149] Selected Action -> charge-1500
#
#
#           [149] Reward -> -0.000
#
#
#           [150] Environment State ->
#                   hour_sin: -0.2794
#                   hour_cos:  0.9602
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  534.68 (kWh)
#                   solar_prod_energy:  42.18 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  7.89 (%)
#                   grid_import_energy:  492.50 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [150] Selected Action -> charge-1500
#
#
#           [150] Reward ->  0.000
#
#
#           [151] Environment State ->
#                   hour_sin:  0.6570
#                   hour_cos:  0.7539
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  557.74 (kWh)
#                   solar_prod_energy:  141.84 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  25.43 (%)
#                   grid_import_energy:  415.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [151] Selected Action -> charge-1500
#
#
#           [151] Reward ->  0.000
#
#
#           [152] Environment State ->
#                   hour_sin:  0.9894
#                   hour_cos: -0.1455
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  553.92 (kWh)
#                   solar_prod_energy:  220.32 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  39.77 (%)
#                   grid_import_energy:  333.60 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [152] Selected Action -> charge-1000
#
#
#           [152] Reward ->  0.000
#
#
#           [153] Environment State ->
#                   hour_sin:  0.4121
#                   hour_cos: -0.9111
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  630.80 (kWh)
#                   solar_prod_energy:  302.80 (kWh)
#                   solar_ctlr_setpoint:  97.35 (%)
#                   solar_vs_load_ratio:  48.00 (%)
#                   grid_import_energy:  328.00 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [153] Selected Action -> charge-1500
#
#
#           [153] Reward ->  0.000
#
#
#           [154] Environment State ->
#                   hour_sin: -0.5440
#                   hour_cos: -0.8391
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  564.38 (kWh)
#                   solar_prod_energy:  321.48 (kWh)
#                   solar_ctlr_setpoint:  86.77 (%)
#                   solar_vs_load_ratio:  56.96 (%)
#                   grid_import_energy:  242.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [154] Selected Action -> charge-1500
#
#
#           [154] Reward ->  0.000
#
#
#           [155] Environment State ->
#                   hour_sin: -1.0000
#                   hour_cos:  0.0044
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  560.51 (kWh)
#                   solar_prod_energy:  313.11 (kWh)
#                   solar_ctlr_setpoint:  80.21 (%)
#                   solar_vs_load_ratio:  55.86 (%)
#                   grid_import_energy:  247.40 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [155] Selected Action -> charge-1000
#
#
#           [155] Reward ->  0.000
#
#
#           [156] Environment State ->
#                   hour_sin: -0.5366
#                   hour_cos:  0.8439
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  540.66 (kWh)
#                   solar_prod_energy:  227.76 (kWh)
#                   solar_ctlr_setpoint:  82.34 (%)
#                   solar_vs_load_ratio:  42.13 (%)
#                   grid_import_energy:  312.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [156] Selected Action -> charge-1000
#
#
#           [156] Reward ->  0.000
#
#
#           [157] Environment State ->
#                   hour_sin:  0.4202
#                   hour_cos:  0.9074
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  583.50 (kWh)
#                   solar_prod_energy:  241.90 (kWh)
#                   solar_ctlr_setpoint:  91.64 (%)
#                   solar_vs_load_ratio:  41.46 (%)
#                   grid_import_energy:  341.60 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [157] Selected Action -> charge-1500
#
#
#           [157] Reward ->  0.000
#
#
#           [158] Environment State ->
#                   hour_sin:  0.9906
#                   hour_cos:  0.1367
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  563.63 (kWh)
#                   solar_prod_energy:  19.73 (kWh)
#                   solar_ctlr_setpoint:  97.15 (%)
#                   solar_vs_load_ratio:  3.50 (%)
#                   grid_import_energy:  543.90 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [158] Selected Action -> charge-1000
#
#
#           [158] Reward ->  0.000
#
#
#           [159] Environment State ->
#                   hour_sin:  0.6503
#                   hour_cos: -0.7597
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  574.48 (kWh)
#                   solar_prod_energy:  1.18 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.21 (%)
#                   grid_import_energy:  573.30 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [159] Selected Action -> charge-1500
#
#
#           [159] Reward ->  0.000
#
#
#           [160] Environment State ->
#                   hour_sin: -0.2879
#                   hour_cos: -0.9577
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  548.31 (kWh)
#                   solar_prod_energy:  0.01 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  548.30 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [160] Selected Action -> charge-1000
#
#
#           [160] Reward ->  0.000
#
#
#           [161] Environment State ->
#                   hour_sin: -0.9614
#                   hour_cos: -0.2752
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  612.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  612.80 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [161] Selected Action -> charge-1000
#
#
#           [161] Reward ->  0.000
#
#
#           [162] Environment State ->
#                   hour_sin: -0.7510
#                   hour_cos:  0.6603
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  639.60 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  639.60 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [162] Selected Action -> charge-1000
#
#
#           [162] Reward ->  0.000
#
#
#           [163] Environment State ->
#                   hour_sin:  0.1499
#                   hour_cos:  0.9887
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  749.20 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  749.20 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [163] Selected Action -> charge-1500
#
#
#           [163] Reward -> -0.000
#
#
#           [164] Environment State ->
#                   hour_sin:  0.9129
#                   hour_cos:  0.4081
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  969.10 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  969.10 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [164] Selected Action -> charge-1500
#
#
#           [164] Reward ->  0.000
#
#
#           [165] Environment State ->
#                   hour_sin:  0.8367
#                   hour_cos: -0.5477
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1375.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1375.30 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [165] Selected Action -> charge-1000
#
#
#           [165] Reward ->  0.000
#
#
#           [166] Environment State ->
#                   hour_sin: -0.0089
#                   hour_cos: -1.0000
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1130.30 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1130.30 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [166] Selected Action -> charge-1500
#
#
#           [166] Reward ->  0.000
#
#
#           [167] Environment State ->
#                   hour_sin: -0.8462
#                   hour_cos: -0.5328
#                   tou_offpeak:  1
#                   tou_standard:  0
#                   tou_peak:  0
#                   day_week:  0
#                   day_saturday:  0
#                   day_sunday:  1
#                   site_load_energy:  1120.80 (kWh)
#                   solar_prod_energy:  0.00 (kWh)
#                   solar_ctlr_setpoint:  100.00 (%)
#                   solar_vs_load_ratio:  0.00 (%)
#                   grid_import_energy:  1120.80 (kWh)
#                   bess_avail_discharge_energy:  3000.00 (kWh)
#                   done: False
#
#
#           [167] Selected Action -> charge-1000
#
#
#           [167] Reward ->  0.000
#
# Episode terminal state reached !
# Final reward:  115.16
